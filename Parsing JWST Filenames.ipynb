# %%
import os

def find_files(directory):
    fits = []
    assn = []
    for root, dirs, files in os.walk(directory):
        for f in files:
            if f.endswith('.fits'):
                fits.append(f)
            elif f.endswith('.json'):
                assn.append(f)
          
    found_files = {'fits': sorted(fits), 'assn': sorted(assn)}
    return found_files

# %%
PATH = "/grp/jwst/ssb/test_build7.1/examples_for_dms"
FILES = find_files(PATH)
print(FILES)
FITS = FILES['fits']
ASSN = FILES['assn']
# Out:
# {'fits': ['cal_001_cal.fits', 'cal_001_cal.fits', 'cal_001_cal_old.fits', 'cal_001_rate.fits', 'cal_002_cal.fits', 'cal_002_cal.fits', 'cal_002_cal_old.fits', 'cal_002_rate.fits', 'cal_003_cal.fits', 'cal_003_cal.fits', 'cal_003_cal_old.fits', 'cal_003_rate.fits', 'cal_004_cal.fits', 'cal_004_cal.fits', 'cal_004_cal_old.fits', 'cal_004_rate.fits', 'cal_005_cal.fits', 'cal_006_cal.fits', 'cal_007_cal.fits', 'cal_008_cal.fits', 'cal_009_cal.fits', 'cal_010_cal.fits', 'cal_011_cal.fits', 'cal_012_cal.fits', 'cal_013_cal.fits', 'cal_014_cal.fits', 'cal_015_cal.fits', 'cal_016_cal.fits', 'cal_017_cal.fits', 'det_image_ch1-short_s3d.fits', 'det_image_ch1-short_x1d.fits', 'det_image_ch2-short_s3d.fits', 'det_image_ch2-short_x1d.fits', 'dispersed_ramp_from_test.fits', 'jw00035001001_01101_00001_mirimage_cal.fits', 'jw00035001001_01101_00001_mirimage_cal.fits', 'jw00035001001_01101_00001_mirimage_rate.fits', 'jw00035001001_01101_00001_mirimage_rate.fits', 'jw00035001001_01101_00001_mirimage_x1d.fits', 'jw00035001001_01101_00001_mirimage_x1d.fits', 'jw00035001001_01101_00002_mirimage_cal.fits', 'jw00035001001_01101_00002_mirimage_rate.fits', 'jw00035001001_01101_00002_mirimage_x1d.fits', 'jw00035001001_01101_00003_mirimage_cal.fits', 'jw00035001001_01101_00003_mirimage_rate.fits', 'jw00035001001_01101_00003_mirimage_x1d.fits', 'jw00035001001_01101_00004_mirimage_bsub.fits', 'jw00035001001_01101_00004_mirimage_cal.fits', 'jw00035001001_01101_00004_mirimage_rate.fits', 'jw00035001001_01101_00004_mirimage_x1d.fits', 'jw00035001001_01101_00005_mirimage_bsub.fits', 'jw00035001001_01101_00005_mirimage_cal.fits', 'jw00035001001_01101_00005_mirimage_rate.fits', 'jw00035001001_01101_00005_mirimage_x1d.fits', 'jw00035001001_01101_00006_mirimage_bsub.fits', 'jw00035001001_01101_00006_mirimage_cal.fits', 'jw00035001001_01101_00006_mirimage_rate.fits', 'jw00035001001_01101_00006_mirimage_x1d.fits', 'jw00035001001_01101_00007_mirimage_bsub.fits', 'jw00035001001_01101_00007_mirimage_cal.fits', 'jw00035001001_01101_00007_mirimage_rate.fits', 'jw00035001001_01101_00007_mirimage_x1d.fits', 'jw00035001001_01101_00008_mirimage_bsub.fits', 'jw00035001001_01101_00008_mirimage_cal.fits', 'jw00035001001_01101_00008_mirimage_rate.fits', 'jw00035001001_01101_00008_mirimage_x1d.fits', 'jw10001001001_01101_00001_mirifushort_cal.fits', 'jw10001001001_01101_00001_mirifushort_rate.fits', 'jw10001001001_01101_00001_mirifushort_s3d.fits', 'jw10001001001_01101_00001_mirifushort_x1d.fits', 'jw10001001001_01101_0001_nrca4_cal.fits', 'jw10001001001_01101_0002_nrca4_cal.fits', 'jw10002001001_01_msa.fits', 'jw10002001001_02101_00001_nrs1_cal.fits', 'jw10002001001_02101_00001_nrs1_rate.fits', 'jw10002001001_02101_00001_nrs1_s2d.fits', 'jw10002001001_02101_00001_nrs1_x1d.fits', 'jw11001001001_01101_00001_NRCA1_uncal.fits', 'jw11111001001_01104_00001_nrcalong_cal.fits', 'jw11111001001_01104_00001_nrcalong_cal.fits', 'jw11111001001_01104_00001_nrcalong_rate.fits', 'jw11111001001_01104_00001_nrcalong_rate.fits', 'jw11111001001_01104_00001_nrcalong_x1d.fits', 'jw11111001001_01104_00001_nrcalong_x1d.fits', 'jw80600-a3002_t001_miri_p750l_s2d.fits', 'jw80600-a3002_t001_miri_p750l_s2d.fits', 'jw80600-a3002_t001_miri_p750l_x1d.fits', 'jw80600-a3002_t001_miri_p750l_x1d.fits', 'jw80600012001_02101_00003_mirimage_calints.fits', 'jw80600012001_02101_00003_mirimage_rateints.fits', 'jw80600012001_02101_00003_mirimage_x1d.fits', 'jw80600013001_02101_00001_mirimage_a3002_crf.fits', 'jw80600013001_02101_00001_mirimage_cal-a3001.fits', 'jw80600013001_02101_00001_mirimage_cal.fits', 'jw80600013001_02101_00001_mirimage_cal.fits', 'jw80600013001_02101_00001_mirimage_rate.fits', 'jw80600013001_02101_00001_mirimage_uncal.fits', 'jw80600013001_02101_00001_mirimage_x1d.fits', 'jw80600013001_02101_00002_mirimage_a3002_crf.fits', 'jw80600013001_02101_00002_mirimage_cal-a3001.fits', 'jw80600013001_02101_00002_mirimage_cal.fits', 'jw80600013001_02101_00002_mirimage_cal.fits', 'jw80600013001_02101_00002_mir ...

# %%
class JWSTFile():
    
    def __init__(self, filename):
        self.filename = filename
        self.full = filename.split(".")[0]
        
        in_chunks = self.full.split("_")
        print(in_chunks)
        if len(in_chunks) < 5:
            print("{0} is not formatted properly".format(filename))
            self.formatted = False
            return
        else:
            self.formatted = True
            
        first = in_chunks[0].split("-")
        if len(first) == 1:
            first = first[0]
            self.program_id = first[2:7]
            self.obs_number = first[7:10]
            self.visit_number = first[10:13]
            self.assn_number = None
        else:
            self.program_id = first[0][2:]
            self.assn_number = first[1]
            self.obs_number = None
            self.visit_number = None
            
        second = in_chunks[1]
        if second.startswith('t'):
            self.target_id = second
            self.source_id = None
            self.visit_group = None
            self.parallel_seq = None
            self.activity_number = None
        elif second.startswith('s'):
            self.source_id = second
            self.target_id = None
            self.visit_group = None
            self.parallel_seq = None
            self.activity_number = None
        else:
            self.visit_group = second[0:2]
            self.parallel_seq = second[2]
            self.activity_number = second[3:]
            self.target_id = None
            self.source_id = None
            
        third = in_chunks[2]
        if third.isdigit():
            self.exposure_number = third
            self.instrument = None
        else:
            self.instrument = third
            self.exposure_number = None
            
        fourth = in_chunks[3:-1]
        if self.assn_number:
            as_string = str(fourth)
            self.optical_elements = as_string[1:-1]    #Strip '[]' from string
            self.detector = "N/A"
        else:
            self.detector = fourth[0]
            self.optical_elements = None
        
        det = self.detector.lower()
        if det.startswith('mir'):
            self.instrument = 'miri'
        elif det.startswith('nrc'):
            self.instrument = 'nircam'
        elif det.startswith('nis'):
            self.instrument = 'niriss'
        elif det.startswith('nrs'):
            self.instrument = 'nirspec'
        else:
            self.detector = None
            
        self.suffix = in_chunks[-1]
        
        self.tuple_ = (self.filename,
                       self.assn_number,
                       self.program_id,
                       self.instrument,
                       self.detector,
                       self.optical_elements,
                       self.target_id,
                       self.source_id,
                       self.obs_number,
                       self.visit_number,
                       self.visit_group,
                       self.parallel_seq,
                       self.activity_number,
                       self.exposure_number,
                       self.suffix
                      )
        
    def __str__(self):
        return self.filename
    
    def show_info(self):
        print("***Info for {0}***".format(self.full))
        print("Program ID:  {0}".format(self.program_id))
        print("Observation number:  {0}".format(self.obs_number))
        print("Visit number:  {0}".format(self.visit_number))
        print("Visit Group:  {0}".format(self.visit_group))
        print("Parallel Sequence ID:  {0}".format(self.parallel_seq))
        print("Activity number:  {0}".format(self.activity_number))
        print("Exposure number:  {0}".format(self.exposure_number))
        print("Detector:  {0}".format(self.detector))
        print("Suffix:  {0}".format(self.suffix))

# %%
import sqlite3

def connect_to_sqlite(db_file):
    conn = sqlite3.connect(':memory:')
    ref = sqlite3.connect(db_file)
    c = conn.cursor()
    
    query = "".join(line for line in ref.iterdump())

    conn.executescript(query)
    
    return c, conn

# %%
c, conn = connect_to_sqlite("jwstfiles.db")
for row in c.execute('SELECT * FROM ami3'):
    print(row)
# Out:
# ('ami', 'Output of ami_analyze step', 'none')
# ('amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none')
# ('aminorm', 'Final single product for the target corrected by the calibrator', 'none')

# %%
import pandas as pd

def add_columns(jw_properties, db_result, stage):
    jw_properties.extend(db_result[1:])
    jw_properties.append(stage)
    return jw_properties

def add_filenames_to_db(files, c, conn):
    columns = ['file',
               'assn_number',
               'program_id',
               'instrument',
               'detector',
               'optical_elements',
               'target_id',
               'source_id',
               'obs_number',
               'visit_number',
               'visit_group',
               'parallel_seq',
               'activity_number',
               'exposure_number',
               'suffix',
               'description',
               'units',
               'stage'
              ]
    df = pd.DataFrame()
    for f in files:
        jw = JWSTFile(f)
        if not jw.formatted:
            continue
            
        jw_list = list(jw.tuple_)
        suffix = []
        suffix.extend(list(c.execute('SELECT * FROM detector1 WHERE suffix=?', [jw.suffix])))
        suffix.extend(list(c.execute('SELECT * FROM image2 WHERE suffix=?', [jw.suffix])))
        suffix.extend(list(c.execute('SELECT * FROM spec2 WHERE suffix=?', [jw.suffix])))
        suffix.extend(list(c.execute('SELECT * FROM ami3 WHERE suffix=?', [jw.suffix])))
        suffix.extend(list(c.execute('SELECT * FROM coron3 WHERE suffix=?', [jw.suffix])))
        suffix.extend(list(c.execute('SELECT * FROM image3 WHERE suffix=?', [jw.suffix])))
        suffix.extend(list(c.execute('SELECT * FROM spec3 WHERE suffix=?', [jw.suffix])))
        suffix.extend(list(c.execute('SELECT * FROM tso3 WHERE suffix=?', [jw.suffix])))
        
        if len(suffix) > 0:
            suffix = suffix[-1]
        else:
            print("Invalid file suffix provided")
            continue

        jw_list = add_columns(jw_list, suffix, '1')
        print(jw_list)
                
        new_row = pd.DataFrame(columns=columns, data=[jw_list])
        df = df.append(new_row, ignore_index=True)
                
    df.to_sql("products", conn, if_exists="replace", dtype='string')
    return df

# %%
frame = add_filenames_to_db(FITS, c, conn)
# Out:
# ['cal', '001', 'cal']
# cal_001_cal.fits is not formatted properly
# ['cal', '001', 'cal']
# cal_001_cal.fits is not formatted properly
# ['cal', '001', 'cal', 'old']
# cal_001_cal_old.fits is not formatted properly
# ['cal', '001', 'rate']
# cal_001_rate.fits is not formatted properly
# ['cal', '002', 'cal']
# cal_002_cal.fits is not formatted properly
# ['cal', '002', 'cal']
# cal_002_cal.fits is not formatted properly
# ['cal', '002', 'cal', 'old']
# cal_002_cal_old.fits is not formatted properly
# ['cal', '002', 'rate']
# cal_002_rate.fits is not formatted properly
# ['cal', '003', 'cal']
# cal_003_cal.fits is not formatted properly
# ['cal', '003', 'cal']
# cal_003_cal.fits is not formatted properly
# ['cal', '003', 'cal', 'old']
# cal_003_cal_old.fits is not formatted properly
# ['cal', '003', 'rate']
# cal_003_rate.fits is not formatted properly
# ['cal', '004', 'cal']
# cal_004_cal.fits is not formatted properly
# ['cal', '004', 'cal']
# cal_004_cal.fits is not formatted properly
# ['cal', '004', 'cal', 'old']
# cal_004_cal_old.fits is not formatted properly
# ['cal', '004', 'rate']
# cal_004_rate.fits is not formatted properly
# ['cal', '005', 'cal']
# cal_005_cal.fits is not formatted properly
# ['cal', '006', 'cal']
# cal_006_cal.fits is not formatted properly
# ['cal', '007', 'cal']
# cal_007_cal.fits is not formatted properly
# ['cal', '008', 'cal']
# cal_008_cal.fits is not formatted properly
# ['cal', '009', 'cal']
# cal_009_cal.fits is not formatted properly
# ['cal', '010', 'cal']
# cal_010_cal.fits is not formatted properly
# ['cal', '011', 'cal']
# cal_011_cal.fits is not formatted properly
# ['cal', '012', 'cal']
# cal_012_cal.fits is not formatted properly
# ['cal', '013', 'cal']
# cal_013_cal.fits is not formatted properly
# ['cal', '014', 'cal']
# cal_014_cal.fits is not formatted properly
# ['cal', '015', 'cal']
# cal_015_cal.fits is not formatted properly
# ['cal', '016', 'cal']
# cal_016_cal.fits is not formatted properly
# ['cal', '017', 'cal']
# cal_017_cal.fits is not formatted properly
# ['det', 'image', 'ch1-short', 's3d']
# det_image_ch1-short_s3d.fits is not formatted properly
# ['det', 'image', 'ch1-short', 'x1d']
# det_image_ch1-short_x1d.fits is not formatted properly
# ['det', 'image', 'ch2-short', 's3d']
# det_image_ch2-short_s3d.fits is not formatted properly
# ['det', 'image', 'ch2-short', 'x1d']
# det_image_ch2-short_x1d.fits is not formatted properly
# ['dispersed', 'ramp', 'from', 'test']
# dispersed_ramp_from_test.fits is not formatted properly
# ['jw00035001001', '01101', '00001', 'mirimage', 'cal']
# ['jw00035001001_01101_00001_mirimage_cal.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw00035001001', '01101', '00001', 'mirimage', 'cal']
# ['jw00035001001_01101_00001_mirimage_cal.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw00035001001', '01101', '00001', 'mirimage', 'rate']
# ['jw00035001001_01101_00001_mirimage_rate.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw00035001001', '01101', '00001', 'mirimage', 'rate']
# ['jw00035001001_01101_00001_mirimage_rate.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw00035001001', '01101', '00001', 'mirimage', 'x1d']
# ['jw00035001001_01101_00001_mirimage_x1d.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00001', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw00035001001', '01101', '00001', 'mirimage', 'x1d']
# ['jw00035001001_01101_00001_mirimage_x1d.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00001', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw00035001001', '01101', '00002', 'mirimage', 'cal']
# ['jw00035001001_01101_00002_mirimage_cal.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00002', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw00035001001', '01101', '00002', 'mirimage', 'rate']
# ['jw00035001001_01101_00002_mirimage_rate.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00002', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw00035001001', '01101', '00002', 'mirimage', 'x1d']
# ['jw00035001001_01101_00002_mirimage_x1d.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00002', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw00035001001', '01101', '00003', 'mirimage', 'cal']
# ['jw00035001001_01101_00003_mirimage_cal.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00003', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw00035001001', '01101', '00003', 'mirimage', 'rate']
# ['jw00035001001_01101_00003_mirimage_rate.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00003', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw00035001001', '01101', '00003', 'mirimage', 'x1d']
# ['jw00035001001_01101_00003_mirimage_x1d.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00003', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw00035001001', '01101', '00004', 'mirimage', 'bsub']
# ['jw00035001001_01101_00004_mirimage_bsub.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00004', 'bsub', '2D background-subtracted spectral data averaged over all integrations', 'DN/s', '1']
# ['jw00035001001', '01101', '00004', 'mirimage', 'cal']
# ['jw00035001001_01101_00004_mirimage_cal.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00004', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw00035001001', '01101', '00004', 'mirimage', 'rate']
# ['jw00035001001_01101_00004_mirimage_rate.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00004', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw00035001001', '01101', '00004', 'mirimage', 'x1d']
# ['jw00035001001_01101_00004_mirimage_x1d.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00004', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw00035001001', '01101', '00005', 'mirimage', 'bsub']
# ['jw00035001001_01101_00005_mirimage_bsub.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00005', 'bsub', '2D background-subtracted spectral data averaged over all integrations', 'DN/s', '1']
# ['jw00035001001', '01101', '00005', 'mirimage', 'cal']
# ['jw00035001001_01101_00005_mirimage_cal.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00005', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw00035001001', '01101', '00005', 'mirimage', 'rate']
# ['jw00035001001_01101_00005_mirimage_rate.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00005', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw00035001001', '01101', '00005', 'mirimage', 'x1d']
# ['jw00035001001_01101_00005_mirimage_x1d.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00005', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw00035001001', '01101', '00006', 'mirimage', 'bsub']
# ['jw00035001001_01101_00006_mirimage_bsub.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00006', 'bsub', '2D background-subtracted spectral data averaged over all integrations', 'DN/s', '1']
# ['jw00035001001', '01101', '00006', 'mirimage', 'cal']
# ['jw00035001001_01101_00006_mirimage_cal.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00006', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw00035001001', '01101', '00006', 'mirimage', 'rate']
# ['jw00035001001_01101_00006_mirimage_rate.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00006', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw00035001001', '01101', '00006', 'mirimage', 'x1d']
# ['jw00035001001_01101_00006_mirimage_x1d.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00006', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw00035001001', '01101', '00007', 'mirimage', 'bsub']
# ['jw00035001001_01101_00007_mirimage_bsub.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00007', 'bsub', '2D background-subtracted spectral data averaged over all integrations', 'DN/s', '1']
# ['jw00035001001', '01101', '00007', 'mirimage', 'cal']
# ['jw00035001001_01101_00007_mirimage_cal.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00007', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw00035001001', '01101', '00007', 'mirimage', 'rate']
# ['jw00035001001_01101_00007_mirimage_rate.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00007', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw00035001001', '01101', '00007', 'mirimage', 'x1d']
# ['jw00035001001_01101_00007_mirimage_x1d.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00007', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw00035001001', '01101', '00008', 'mirimage', 'bsub']
# ['jw00035001001_01101_00008_mirimage_bsub.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00008', 'bsub', '2D background-subtracted spectral data averaged over all integrations', 'DN/s', '1']
# ['jw00035001001', '01101', '00008', 'mirimage', 'cal']
# ['jw00035001001_01101_00008_mirimage_cal.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00008', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw00035001001', '01101', '00008', 'mirimage', 'rate']
# ['jw00035001001_01101_00008_mirimage_rate.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00008', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw00035001001', '01101', '00008', 'mirimage', 'x1d']
# ['jw00035001001_01101_00008_mirimage_x1d.fits', None, '00035', 'miri', 'mirimage', None, None, None, '001', '001', '01', '1', '01', '00008', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw10001001001', '01101', '00001', 'mirifushort', 'cal']
# ['jw10001001001_01101_00001_mirifushort_cal.fits', None, '10001', 'miri', 'mirifushort', None, None, None, '001', '001', '01', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw10001001001', '01101', '00001', 'mirifushort', 'rate']
# ['jw10001001001_01101_00001_mirifushort_rate.fits', None, '10001', 'miri', 'mirifushort', None, None, None, '001', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw10001001001', '01101', '00001', 'mirifushort', 's3d']
# ['jw10001001001_01101_00001_mirifushort_s3d.fits', None, '10001', 'miri', 'mirifushort', None, None, None, '001', '001', '01', '1', '01', '00001', 's3d', '3D rectified and combined spectral cube', 'none', '1']
# ['jw10001001001', '01101', '00001', 'mirifushort', 'x1d']
# ['jw10001001001_01101_00001_mirifushort_x1d.fits', None, '10001', 'miri', 'mirifushort', None, None, None, '001', '001', '01', '1', '01', '00001', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw10001001001', '01101', '0001', 'nrca4', 'cal']
# ['jw10001001001_01101_0001_nrca4_cal.fits', None, '10001', 'nircam', 'nrca4', None, None, None, '001', '001', '01', '1', '01', '0001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw10001001001', '01101', '0002', 'nrca4', 'cal']
# ['jw10001001001_01101_0002_nrca4_cal.fits', None, '10001', 'nircam', 'nrca4', None, None, None, '001', '001', '01', '1', '01', '0002', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw10002001001', '01', 'msa']
# jw10002001001_01_msa.fits is not formatted properly
# ['jw10002001001', '02101', '00001', 'nrs1', 'cal']
# ['jw10002001001_02101_00001_nrs1_cal.fits', None, '10002', 'nirspec', 'nrs1', None, None, None, '001', '001', '02', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw10002001001', '02101', '00001', 'nrs1', 'rate']
# ['jw10002001001_02101_00001_nrs1_rate.fits', None, '10002', 'nirspec', 'nrs1', None, None, None, '001', '001', '02', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw10002001001', '02101', '00001', 'nrs1', 's2d']
# ['jw10002001001_02101_00001_nrs1_s2d.fits', None, '10002', 'nirspec', 'nrs1', None, None, None, '001', '001', '02', '1', '01', '00001', 's2d', '2D resampled+combined spectroscopic image', 'none', '1']
# ['jw10002001001', '02101', '00001', 'nrs1', 'x1d']
# ['jw10002001001_02101_00001_nrs1_x1d.fits', None, '10002', 'nirspec', 'nrs1', None, None, None, '001', '001', '02', '1', '01', '00001', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw11001001001', '01101', '00001', 'NRCA1', 'uncal']
# ['jw11001001001_01101_00001_NRCA1_uncal.fits', None, '11001', 'nircam', 'NRCA1', None, None, None, '001', '001', '01', '1', '01', '00001', 'uncal', 'Raw 4D exposure data', 'DN', '1']
# ['jw11111001001', '01104', '00001', 'nrcalong', 'cal']
# ['jw11111001001_01104_00001_nrcalong_cal.fits', None, '11111', 'nircam', 'nrcalong', None, None, None, '001', '001', '01', '1', '04', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw11111001001', '01104', '00001', 'nrcalong', 'cal']
# ['jw11111001001_01104_00001_nrcalong_cal.fits', None, '11111', 'nircam', 'nrcalong', None, None, None, '001', '001', '01', '1', '04', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw11111001001', '01104', '00001', 'nrcalong', 'rate']
# ['jw11111001001_01104_00001_nrcalong_rate.fits', None, '11111', 'nircam', 'nrcalong', None, None, None, '001', '001', '01', '1', '04', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw11111001001', '01104', '00001', 'nrcalong', 'rate']
# ['jw11111001001_01104_00001_nrcalong_rate.fits', None, '11111', 'nircam', 'nrcalong', None, None, None, '001', '001', '01', '1', '04', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw11111001001', '01104', '00001', 'nrcalong', 'x1d']
# ['jw11111001001_01104_00001_nrcalong_x1d.fits', None, '11111', 'nircam', 'nrcalong', None, None, None, '001', '001', '01', '1', '04', '00001', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw11111001001', '01104', '00001', 'nrcalong', 'x1d']
# ['jw11111001001_01104_00001_nrcalong_x1d.fits', None, '11111', 'nircam', 'nrcalong', None, None, None, '001', '001', '01', '1', '04', '00001', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw80600-a3002', 't001', 'miri', 'p750l', 's2d']
# ['jw80600-a3002_t001_miri_p750l_s2d.fits', 'a3002', '80600', 'miri', None, "'p750l'", 't001', None, None, None, None, None, None, None, 's2d', '2D resampled+combined spectroscopic image', 'none', '1']
# ['jw80600-a3002', 't001', 'miri', 'p750l', 's2d']
# ['jw80600-a3002_t001_miri_p750l_s2d.fits', 'a3002', '80600', 'miri', None, "'p750l'", 't001', None, None, None, None, None, None, None, 's2d', '2D resampled+combined spectroscopic image', 'none', '1']
# ['jw80600-a3002', 't001', 'miri', 'p750l', 'x1d']
# ['jw80600-a3002_t001_miri_p750l_x1d.fits', 'a3002', '80600', 'miri', None, "'p750l'", 't001', None, None, None, None, None, None, None, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw80600-a3002', 't001', 'miri', 'p750l', 'x1d']
# ['jw80600-a3002_t001_miri_p750l_x1d.fits', 'a3002', '80600', 'miri', None, "'p750l'", 't001', None, None, None, None, None, None, None, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw80600012001', '02101', '00003', 'mirimage', 'calints']
# ['jw80600012001_02101_00003_mirimage_calints.fits', None, '80600', 'miri', 'mirimage', None, None, None, '012', '001', '02', '1', '01', '00003', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw80600012001', '02101', '00003', 'mirimage', 'rateints']
# ['jw80600012001_02101_00003_mirimage_rateints.fits', None, '80600', 'miri', 'mirimage', None, None, None, '012', '001', '02', '1', '01', '00003', 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', '1']
# ['jw80600012001', '02101', '00003', 'mirimage', 'x1d']
# ['jw80600012001_02101_00003_mirimage_x1d.fits', None, '80600', 'miri', 'mirimage', None, None, None, '012', '001', '02', '1', '01', '00003', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw80600013001', '02101', '00001', 'mirimage', 'a3002', 'crf']
# ['jw80600013001_02101_00001_mirimage_a3002_crf.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00001', 'crf', 'Copy of _cal with DQ array updated by outlier_detection step', 'DN/s', '1']
# ['jw80600013001', '02101', '00001', 'mirimage', 'cal-a3001']
# Invalid file suffix provided
# ['jw80600013001', '02101', '00001', 'mirimage', 'cal']
# ['jw80600013001_02101_00001_mirimage_cal.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw80600013001', '02101', '00001', 'mirimage', 'cal']
# ['jw80600013001_02101_00001_mirimage_cal.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw80600013001', '02101', '00001', 'mirimage', 'rate']
# ['jw80600013001_02101_00001_mirimage_rate.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw80600013001', '02101', '00001', 'mirimage', 'uncal']
# ['jw80600013001_02101_00001_mirimage_uncal.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00001', 'uncal', 'Raw 4D exposure data', 'DN', '1']
# ['jw80600013001', '02101', '00001', 'mirimage', 'x1d']
# ['jw80600013001_02101_00001_mirimage_x1d.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00001', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw80600013001', '02101', '00002', 'mirimage', 'a3002', 'crf']
# ['jw80600013001_02101_00002_mirimage_a3002_crf.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00002', 'crf', 'Copy of _cal with DQ array updated by outlier_detection step', 'DN/s', '1']
# ['jw80600013001', '02101', '00002', 'mirimage', 'cal-a3001']
# Invalid file suffix provided
# ['jw80600013001', '02101', '00002', 'mirimage', 'cal']
# ['jw80600013001_02101_00002_mirimage_cal.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00002', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw80600013001', '02101', '00002', 'mirimage', 'cal']
# ['jw80600013001_02101_00002_mirimage_cal.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00002', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw80600013001', '02101', '00002', 'mirimage', 'rate']
# ['jw80600013001_02101_00002_mirimage_rate.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00002', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw80600013001', '02101', '00002', 'mirimage', 'uncal']
# ['jw80600013001_02101_00002_mirimage_uncal.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00002', 'uncal', 'Raw 4D exposure data', 'DN', '1']
# ['jw80600013001', '02101', '00002', 'mirimage', 'x1d']
# ['jw80600013001_02101_00002_mirimage_x1d.fits', None, '80600', 'miri', 'mirimage', None, None, None, '013', '001', '02', '1', '01', '00002', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw82600047001', '02102', '00001', 'nrcb3', 'calints']
# ['jw82600047001_02102_00001_nrcb3_calints.fits', None, '82600', 'nircam', 'nrcb3', None, None, None, '047', '001', '02', '1', '02', '00001', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw82600047001', '02102', '00001', 'nrcb3', 'rate']
# ['jw82600047001_02102_00001_nrcb3_rate.fits', None, '82600', 'nircam', 'nrcb3', None, None, None, '047', '001', '02', '1', '02', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw82600047001', '02102', '00001', 'nrcb3', 'rateints']
# ['jw82600047001_02102_00001_nrcb3_rateints.fits', None, '82600', 'nircam', 'nrcb3', None, None, None, '047', '001', '02', '1', '02', '00001', 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', '1']
# ['jw82600047001', '02102', '00001', 'nrcb3', 'uncal']
# ['jw82600047001_02102_00001_nrcb3_uncal.fits', None, '82600', 'nircam', 'nrcb3', None, None, None, '047', '001', '02', '1', '02', '00001', 'uncal', 'Raw 4D exposure data', 'DN', '1']
# ['jw82600049001', '02102', '00001', 'nrcblong', 'calints']
# ['jw82600049001_02102_00001_nrcblong_calints.fits', None, '82600', 'nircam', 'nrcblong', None, None, None, '049', '001', '02', '1', '02', '00001', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw82600049001', '02102', '00001', 'nrcblong', 'rate']
# ['jw82600049001_02102_00001_nrcblong_rate.fits', None, '82600', 'nircam', 'nrcblong', None, None, None, '049', '001', '02', '1', '02', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw82600049001', '02102', '00001', 'nrcblong', 'rateints']
# ['jw82600049001_02102_00001_nrcblong_rateints.fits', None, '82600', 'nircam', 'nrcblong', None, None, None, '049', '001', '02', '1', '02', '00001', 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', '1']
# ['jw82600049001', '02102', '00001', 'nrcblong', 'uncal']
# ['jw82600049001_02102_00001_nrcblong_uncal.fits', None, '82600', 'nircam', 'nrcblong', None, None, None, '049', '001', '02', '1', '02', '00001', 'uncal', 'Raw 4D exposure data', 'DN', '1']
# ['jw82600051001', '02102', '00001', 'nrcalong', 'calints']
# ['jw82600051001_02102_00001_nrcalong_calints.fits', None, '82600', 'nircam', 'nrcalong', None, None, None, '051', '001', '02', '1', '02', '00001', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw82600051001', '02102', '00001', 'nrcalong', 'rate']
# ['jw82600051001_02102_00001_nrcalong_rate.fits', None, '82600', 'nircam', 'nrcalong', None, None, None, '051', '001', '02', '1', '02', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw82600051001', '02102', '00001', 'nrcalong', 'rateints']
# ['jw82600051001_02102_00001_nrcalong_rateints.fits', None, '82600', 'nircam', 'nrcalong', None, None, None, '051', '001', '02', '1', '02', '00001', 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', '1']
# ['jw82600051001', '02102', '00001', 'nrcalong', 'uncal']
# ['jw82600051001_02102_00001_nrcalong_uncal.fits', None, '82600', 'nircam', 'nrcalong', None, None, None, '051', '001', '02', '1', '02', '00001', 'uncal', 'Raw 4D exposure data', 'DN', '1']
# ['jw84600007001', '02101', '00001', 'nrs1', 'cal']
# ['jw84600007001_02101_00001_nrs1_cal.fits', None, '84600', 'nirspec', 'nrs1', None, None, None, '007', '001', '02', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw84600007001', '02101', '00001', 'nrs1', 'rate']
# ['jw84600007001_02101_00001_nrs1_rate.fits', None, '84600', 'nirspec', 'nrs1', None, None, None, '007', '001', '02', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw84600007001', '02101', '00001', 'nrs1', 's3d']
# ['jw84600007001_02101_00001_nrs1_s3d.fits', None, '84600', 'nirspec', 'nrs1', None, None, None, '007', '001', '02', '1', '01', '00001', 's3d', '3D rectified and combined spectral cube', 'none', '1']
# ['jw84600007001', '02101', '00001', 'nrs1', 'x1d']
# ['jw84600007001_02101_00001_nrs1_x1d.fits', None, '84600', 'nirspec', 'nrs1', None, None, None, '007', '001', '02', '1', '01', '00001', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw87600-a3001', 't001', 'niriss', 'clear-gr700xd', 'x1dints']
# ['jw87600-a3001_t001_niriss_clear-gr700xd_x1dints.fits', 'a3001', '87600', 'niriss', None, "'clear-gr700xd'", 't001', None, None, None, None, None, None, None, 'x1dints', 'Extracted 1D spectra per integration', 'flux', '1']
# ['jw87600-a3001', 't001', 'niriss', 'f480m-nrm', 'amiavg']
# ['jw87600-a3001_t001_niriss_f480m-nrm_amiavg.fits', 'a3001', '87600', 'niriss', None, "'f480m-nrm'", 't001', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', '1']
# ['jw87600-a3001', 't001', 'niriss', 'f480m-nrm', 'aminorm']
# ['jw87600-a3001_t001_niriss_f480m-nrm_aminorm.fits', 'a3001', '87600', 'niriss', None, "'f480m-nrm'", 't001', None, None, None, None, None, None, None, 'aminorm', 'Final single product for the target corrected by the calibrator', 'none', '1']
# ['jw87600-a3001', 't002', 'niriss', 'f480m-nrm', 'amiavg']
# ['jw87600-a3001_t002_niriss_f480m-nrm_amiavg.fits', 'a3001', '87600', 'niriss', None, "'f480m-nrm'", 't002', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', '1']
# ['jw87600-a3001', 't1', 'niriss', 'f480m-nrm', 'amiavg']
# ['jw87600-a3001_t1_niriss_f480m-nrm_amiavg.fits', 'a3001', '87600', 'niriss', None, "'f480m-nrm'", 't1', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', '1']
# ['jw87600-a3001', 't1', 'niriss', 'f480m-nrm', 'aminorm']
# ['jw87600-a3001_t1_niriss_f480m-nrm_aminorm.fits', 'a3001', '87600', 'niriss', None, "'f480m-nrm'", 't1', None, None, None, None, None, None, None, 'aminorm', 'Final single product for the target corrected by the calibrator', 'none', '1']
# ['jw87600-a3001', 't2', 'niriss', 'f480m-nrm', 'amiavg']
# ['jw87600-a3001_t2_niriss_f480m-nrm_amiavg.fits', 'a3001', '87600', 'niriss', None, "'f480m-nrm'", 't2', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', '1']
# ['jw87600-a3002', 't001', 'niriss', 'f480m-nrm', 'amiavg']
# ['jw87600-a3002_t001_niriss_f480m-nrm_amiavg.fits', 'a3002', '87600', 'niriss', None, "'f480m-nrm'", 't001', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', '1']
# ['jw87600-a3002', 't001', 'niriss', 'f480m-nrm', 'aminorm']
# ['jw87600-a3002_t001_niriss_f480m-nrm_aminorm.fits', 'a3002', '87600', 'niriss', None, "'f480m-nrm'", 't001', None, None, None, None, None, None, None, 'aminorm', 'Final single product for the target corrected by the calibrator', 'none', '1']
# ['jw87600-a3002', 't002', 'niriss', 'f480m-nrm', 'amiavg']
# ['jw87600-a3002_t002_niriss_f480m-nrm_amiavg.fits', 'a3002', '87600', 'niriss', None, "'f480m-nrm'", 't002', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', '1']
# ['jw87600017001', '02101', '00002', 'nis', 'cal']
# ['jw87600017001_02101_00002_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '017', '001', '02', '1', '01', '00002', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600017001', '02101', '00002', 'nis', 'cal']
# ['jw87600017001_02101_00002_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '017', '001', '02', '1', '01', '00002', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600017001', '02101', '00002', 'nis', 'rate']
# ['jw87600017001_02101_00002_nis_rate.fits', None, '87600', 'niriss', 'nis', None, None, None, '017', '001', '02', '1', '01', '00002', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw87600017001', '02101', '00002', 'nis', 'rate']
# ['jw87600017001_02101_00002_nis_rate.fits', None, '87600', 'niriss', 'nis', None, None, None, '017', '001', '02', '1', '01', '00002', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw87600017001', '02101', '00002', 'nis', 'x1d']
# ['jw87600017001_02101_00002_nis_x1d.fits', None, '87600', 'niriss', 'nis', None, None, None, '017', '001', '02', '1', '01', '00002', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw87600017001', '02101', '00002', 'nis', 'x1d']
# ['jw87600017001_02101_00002_nis_x1d.fits', None, '87600', 'niriss', 'nis', None, None, None, '017', '001', '02', '1', '01', '00002', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jw87600024001', '02101', '00001', 'nis', 'a3001', 'crf']
# ['jw87600024001_02101_00001_nis_a3001_crf.fits', None, '87600', 'niriss', 'nis', None, None, None, '024', '001', '02', '1', '01', '00001', 'crf', 'Copy of _cal with DQ array updated by outlier_detection step', 'DN/s', '1']
# ['jw87600024001', '02101', '00001', 'nis', 'calints']
# ['jw87600024001_02101_00001_nis_calints.fits', None, '87600', 'niriss', 'nis', None, None, None, '024', '001', '02', '1', '01', '00001', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw87600024001', '02101', '00001', 'nis', 'rateints']
# ['jw87600024001_02101_00001_nis_rateints.fits', None, '87600', 'niriss', 'nis', None, None, None, '024', '001', '02', '1', '01', '00001', 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', '1']
# ['jw87600024001', '02101', '00001', 'nis', 'uncal']
# ['jw87600024001_02101_00001_nis_uncal.fits', None, '87600', 'niriss', 'nis', None, None, None, '024', '001', '02', '1', '01', '00001', 'uncal', 'Raw 4D exposure data', 'DN', '1']
# ['jw87600024001', '02101', '00001', 'nis', 'x1dints']
# ['jw87600024001_02101_00001_nis_x1dints.fits', None, '87600', 'niriss', 'nis', None, None, None, '024', '001', '02', '1', '01', '00001', 'x1dints', 'Extracted 1D spectra per integration', 'flux', '1']
# ['jw87600027001', '02101', '00001', 'nis', 'a3001', 'ami']
# ['jw87600027001_02101_00001_nis_a3001_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00001', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00001', 'nis', 'ami']
# ['jw87600027001_02101_00001_nis_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00001', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00001', 'nis', 'cal']
# ['jw87600027001_02101_00001_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00001', 'nis', 'cal']
# ['jw87600027001_02101_00001_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00001', 'nis', 'cal']
# ['jw87600027001_02101_00001_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00001', 'nis', 'rate']
# ['jw87600027001_02101_00001_nis_rate.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw87600027001', '02101', '00001', 'nis', 'uncal']
# ['jw87600027001_02101_00001_nis_uncal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00001', 'uncal', 'Raw 4D exposure data', 'DN', '1']
# ['jw87600027001', '02101', '00002', 'nis', 'a3001', 'ami']
# ['jw87600027001_02101_00002_nis_a3001_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00002', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00002', 'nis', 'ami']
# ['jw87600027001_02101_00002_nis_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00002', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00002', 'nis', 'cal']
# ['jw87600027001_02101_00002_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00002', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00002', 'nis', 'cal']
# ['jw87600027001_02101_00002_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00002', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00003', 'nis', 'a3001', 'ami']
# ['jw87600027001_02101_00003_nis_a3001_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00003', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00003', 'nis', 'ami']
# ['jw87600027001_02101_00003_nis_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00003', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00003', 'nis', 'cal']
# ['jw87600027001_02101_00003_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00003', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00003', 'nis', 'cal']
# ['jw87600027001_02101_00003_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00003', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00004', 'nis', 'a3001', 'ami']
# ['jw87600027001_02101_00004_nis_a3001_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00004', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00004', 'nis', 'ami']
# ['jw87600027001_02101_00004_nis_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00004', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00004', 'nis', 'cal']
# ['jw87600027001_02101_00004_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00004', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00004', 'nis', 'cal']
# ['jw87600027001_02101_00004_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00004', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00005', 'nis', 'a3001', 'ami']
# ['jw87600027001_02101_00005_nis_a3001_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00005', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00005', 'nis', 'ami']
# ['jw87600027001_02101_00005_nis_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00005', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00005', 'nis', 'cal']
# ['jw87600027001_02101_00005_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00005', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00005', 'nis', 'cal']
# ['jw87600027001_02101_00005_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00005', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00006', 'nis', 'a3001', 'ami']
# ['jw87600027001_02101_00006_nis_a3001_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00006', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00006', 'nis', 'ami']
# ['jw87600027001_02101_00006_nis_ami.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00006', 'ami', 'Output of ami_analyze step', 'none', '1']
# ['jw87600027001', '02101', '00006', 'nis', 'cal']
# ['jw87600027001_02101_00006_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00006', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw87600027001', '02101', '00006', 'nis', 'cal']
# ['jw87600027001_02101_00006_nis_cal.fits', None, '87600', 'niriss', 'nis', None, None, None, '027', '001', '02', '1', '01', '00006', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw93065002001', '02101', '00001', 'nrca1', 'a3001', 'crfints']
# ['jw93065002001_02101_00001_nrca1_a3001_crfints.fits', None, '93065', 'nircam', 'nrca1', None, None, None, '002', '001', '02', '1', '01', '00001', 'crfints', '3D calibrated data with DQ array updated by outlier_detection step', 'DN/s', '1']
# ['jw93065002001', '02101', '00001', 'nrca1', 'calints']
# ['jw93065002001_02101_00001_nrca1_calints.fits', None, '93065', 'nircam', 'nrca1', None, None, None, '002', '001', '02', '1', '01', '00001', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw93065002001', '02101', '00001', 'nrca1', 'rate']
# ['jw93065002001_02101_00001_nrca1_rate.fits', None, '93065', 'nircam', 'nrca1', None, None, None, '002', '001', '02', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw93065002001', '02101', '00001', 'nrca1', 'rateints']
# ['jw93065002001_02101_00001_nrca1_rateints.fits', None, '93065', 'nircam', 'nrca1', None, None, None, '002', '001', '02', '1', '01', '00001', 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', '1']
# ['jw93065002001', '02101', '00001', 'nrca1', 'uncal']
# ['jw93065002001_02101_00001_nrca1_uncal.fits', None, '93065', 'nircam', 'nrca1', None, None, None, '002', '001', '02', '1', '01', '00001', 'uncal', 'Raw 4D exposure data', 'DN', '1']
# ['jw94015001002', '02104', '00001', 'nrcalong', 'rate']
# ['jw94015001002_02104_00001_nrcalong_rate.fits', None, '94015', 'nircam', 'nrcalong', None, None, None, '001', '002', '02', '1', '04', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jw94015002001', '02101', '00001', 'mirimage', 'cal']
# ['jw94015002001_02101_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '02101', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002001', '02102', '00001', 'mirimage', 'cal']
# ['jw94015002001_02102_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '02', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '02102', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002001', '02103', '00001', 'mirimage', 'cal']
# ['jw94015002001_02103_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '03', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '02103', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002001', '02104', '00001', 'mirimage', 'cal']
# ['jw94015002001_02104_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '04', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '02104', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002001', '02105', '00001', 'mirimage', 'cal']
# ['jw94015002001_02105_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '05', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '02105', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002001', '02106', '00001', 'mirimage', 'cal']
# ['jw94015002001_02106_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '06', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '02106', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002001', '02107', '00001', 'mirimage', 'cal']
# ['jw94015002001_02107_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '07', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '02107', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002001', '02108', '00001', 'mirimage', 'cal']
# ['jw94015002001_02108_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '08', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '02108', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002001', '02109', '00001', 'mirimage', 'cal']
# ['jw94015002001_02109_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '09', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '02109', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002001', '0210A', '00001', 'mirimage', 'cal']
# ['jw94015002001_0210A_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '0A', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '0210A', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002001', '0210B', '00001', 'mirimage', 'cal']
# ['jw94015002001_0210B_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '0B', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '0210B', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002001', '0210C', '00001', 'mirimage', 'cal']
# ['jw94015002001_0210C_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '001', '02', '1', '0C', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002001', '0210C', '00001', 'mirimage', 'cal', 'group']
# Invalid file suffix provided
# ['jw94015002002', '02101', '00001', 'mirimage', 'cal']
# ['jw94015002002_02101_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '002', '02', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002002', '02102', '00001', 'mirimage', 'cal']
# ['jw94015002002_02102_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '002', '02', '1', '02', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002002', '02103', '00001', 'mirimage', 'cal']
# ['jw94015002002_02103_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '002', '02', '1', '03', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002002', '02104', '00001', 'mirimage', 'cal']
# ['jw94015002002_02104_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '002', '02', '1', '04', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002002', '02105', '00001', 'mirimage', 'cal']
# ['jw94015002002_02105_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '002', '02', '1', '05', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002002', '02106', '00001', 'mirimage', 'cal']
# ['jw94015002002_02106_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '002', '02', '1', '06', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002002', '02107', '00001', 'mirimage', 'cal']
# ['jw94015002002_02107_00001_mirimage_cal.fits', None, '94015', 'miri', 'mirimage', None, None, None, '002', '002', '02', '1', '07', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jw94015002002', '02108', '00001', 'mirimage', 'cal']
# ...
# ['jw9999947001', '02102', '00003', 'nrcb3', 'calints']
# ['jw9999947001_02102_00003_nrcb3_calints.fits', None, '99999', 'nircam', 'nrcb3', None, None, None, '470', '01', '02', '1', '02', '00003', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw9999947001', '02102', '00003', 'nrcb3', 'calints']
# ['jw9999947001_02102_00003_nrcb3_calints.fits', None, '99999', 'nircam', 'nrcb3', None, None, None, '470', '01', '02', '1', '02', '00003', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw9999947001', '02102', '00003', 'nrcb3', 'rateints']
# ['jw9999947001_02102_00003_nrcb3_rateints.fits', None, '99999', 'nircam', 'nrcb3', None, None, None, '470', '01', '02', '1', '02', '00003', 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', '1']
# ['jw9999947001', '02102', '00004', 'nrcb3', 'calints']
# ['jw9999947001_02102_00004_nrcb3_calints.fits', None, '99999', 'nircam', 'nrcb3', None, None, None, '470', '01', '02', '1', '02', '00004', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw9999947001', '02102', '00004', 'nrcb3', 'calints']
# ['jw9999947001_02102_00004_nrcb3_calints.fits', None, '99999', 'nircam', 'nrcb3', None, None, None, '470', '01', '02', '1', '02', '00004', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw9999947001', '02102', '00004', 'nrcb3', 'rateints']
# ['jw9999947001_02102_00004_nrcb3_rateints.fits', None, '99999', 'nircam', 'nrcb3', None, None, None, '470', '01', '02', '1', '02', '00004', 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', '1']
# ['jw9999947001', '02102', '00005', 'nrcb3', 'calints']
# ['jw9999947001_02102_00005_nrcb3_calints.fits', None, '99999', 'nircam', 'nrcb3', None, None, None, '470', '01', '02', '1', '02', '00005', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw9999947001', '02102', '00005', 'nrcb3', 'calints']
# ['jw9999947001_02102_00005_nrcb3_calints.fits', None, '99999', 'nircam', 'nrcb3', None, None, None, '470', '01', '02', '1', '02', '00005', 'calints', 'Calibrated slope images for each integration', 'DN/s', '1']
# ['jw9999947001', '02102', '00005', 'nrcb3', 'rateints']
# ['jw9999947001_02102_00005_nrcb3_rateints.fits', None, '99999', 'nircam', 'nrcb3', None, None, None, '470', '01', '02', '1', '02', '00005', 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', '1']
# ['jwst', 'nircam', 'photom', '0050']
# jwst_nircam_photom_0050.fits is not formatted properly
# ['jwst', 'nircam', 'psfmask', 'somb']
# jwst_nircam_psfmask_somb.fits is not formatted properly
# ['jwst', 'nircam', 'psfmask', 'somb']
# jwst_nircam_psfmask_somb.fits is not formatted properly
# ['jwtest1001001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1001001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '001', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1002001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1002001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '002', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1003001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1003001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '003', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1004001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1004001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '004', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1005001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1005001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '005', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1006001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1006001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '006', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1007001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1007001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '007', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1008001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1008001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '008', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1009001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1009001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '009', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1010001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1010001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '010', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1011001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1011001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '011', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1012001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1012001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '012', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1013001', '01101', '00001', 'NRS1', 'cal']
# ['jwtest1013001_01101_00001_NRS1_cal.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '013', '001', '01', '1', '01', '00001', 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', '1']
# ['jwtest1013001', '01101', '00001', 'NRS1', 'rate']
# ['jwtest1013001_01101_00001_NRS1_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '013', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1013001', '01101', '00001', 'NRS1', 's2d']
# ['jwtest1013001_01101_00001_NRS1_s2d.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '013', '001', '01', '1', '01', '00001', 's2d', '2D resampled+combined spectroscopic image', 'none', '1']
# ['jwtest1013001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1013001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '013', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1013001', '01101', '00001', 'NRS1', 'x1d']
# ['jwtest1013001_01101_00001_NRS1_x1d.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '013', '001', '01', '1', '01', '00001', 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', '1']
# ['jwtest1014001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1014001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '014', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1015001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1015001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '015', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1016001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1016001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '016', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1017001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1017001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '017', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1018001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1018001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '018', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1019001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1019001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '019', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1020001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1020001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '020', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1021001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1021001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '021', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1022001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1022001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '022', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1023001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1023001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '023', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1024001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1024001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '024', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1025001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1025001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '025', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1026001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1026001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '026', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1027001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1027001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '027', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1028001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1028001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '028', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1029001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1029001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '029', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1030001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1030001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '030', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1031001', '01101', '00001', 'NRS1', 'uncal', 'rate']
# ['jwtest1031001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, '031', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['jwtest1032001', '01101', '00001', 'NRS2', 'uncal', 'rate']
# ['jwtest1032001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, '032', '001', '01', '1', '01', '00001', 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', '1']
# ['real', 'soss', 'disp', 'mode', '250', '8', '96', '2048', 'uncal']
# ['real_soss_disp_mode_250_8_96_2048_uncal.fits', None, 'al', 'disp', None, None, None, 'soss', '', '', None, None, None, None, 'uncal', 'Raw 4D exposure data', 'DN', '1']
# ['template']
# template.fits is not formatted properly
# ['template', 'uncal']
# template_uncal.fits is not formatted properly
# ['test', 'disperse', 'f335m', 'rate', 'updated']
# Invalid file suffix provided
# ['test', 'psf1', 'cal']
# test_psf1_cal.fits is not formatted properly
# ['test', 'psf1', 'calints']
# test_psf1_calints.fits is not formatted properly
# ['test', 'psf2', 'cal']
# test_psf2_cal.fits is not formatted properly
# ['test', 'psf2', 'calints']
# test_psf2_calints.fits is not formatted properly
# ['test', 'psf3', 'cal']
# test_psf3_cal.fits is not formatted properly
# ['test', 'psf3', 'calints']
# test_psf3_calints.fits is not formatted properly
# ['test', 'targ1', 'cal']
# test_targ1_cal.fits is not formatted properly
# ['test', 'targ1', 'calints']
# test_targ1_calints.fits is not formatted properly
# ['test', 'targ1', 'prewcs']
# test_targ1_prewcs.fits is not formatted properly
# ['test', 'targ1', 'psfalign']
# test_targ1_psfalign.fits is not formatted properly
# ['test', 'targ1', 'psfsub']
# test_targ1_psfsub.fits is not formatted properly
# ['test', 'targ2', 'cal']
# test_targ2_cal.fits is not formatted properly
# ['test', 'targ2', 'calints']
# test_targ2_calints.fits is not formatted properly
# ['test', 'targ2', 'prewcs']
# test_targ2_prewcs.fits is not formatted properly
# ['test', 'targ2', 'psfalign']
# test_targ2_psfalign.fits is not formatted properly
# ['test', 'targ2', 'psfsub']
# test_targ2_psfsub.fits is not formatted properly
# ['test', 'targ3', 'cal']
# test_targ3_cal.fits is not formatted properly
# ['test', 'target1', 'psfstack']
# test_target1_psfstack.fits is not formatted properly

# %%
frame[40:50]
# Out:
#                                             file assn_number program_id  \
# 40       jw10002001001_02101_00001_nrs1_s2d.fits        None      10002
# 41       jw10002001001_02101_00001_nrs1_x1d.fits        None      10002
# 42    jw11001001001_01101_00001_NRCA1_uncal.fits        None      11001
# 43   jw11111001001_01104_00001_nrcalong_cal.fits        None      11111
# 44   jw11111001001_01104_00001_nrcalong_cal.fits        None      11111
# 45  jw11111001001_01104_00001_nrcalong_rate.fits        None      11111
# 46  jw11111001001_01104_00001_nrcalong_rate.fits        None      11111
# 47   jw11111001001_01104_00001_nrcalong_x1d.fits        None      11111
# 48   jw11111001001_01104_00001_nrcalong_x1d.fits        None      11111
# 49        jw80600-a3002_t001_miri_p750l_s2d.fits       a3002      80600
#
#    instrument  detector optical_elements target_id source_id obs_number  \
# 40    nirspec      nrs1             None      None      None        001
# 41    nirspec      nrs1             None      None      None        001
# 42     nircam     NRCA1             None      None      None        001
# 43     nircam  nrcalong             None      None      None        001
# 44     nircam  nrcalong             None      None      None        001
# 45     nircam  nrcalong             None      None      None        001
# 46     nircam  nrcalong             None      None      None        001
# 47     nircam  nrcalong             None      None      None        001
# 48     nircam  nrcalong             None      None      None        001
# 49       miri      None          'p750l'      t001      None       None
#
#    visit_number visit_group parallel_seq activity_number exposure_number  \
# 40          001          02            1              01           00001
# 41          001          02            1              01           00001
# 42          001          01            1              01           00001
# 43          001          01            1              04           00001
# 44          001          01            1              04           00001
# 45          001          01            1              04           00001
# 46          001          01            1              04           00001
# 47          001          01            1              04           00001
# 48          001          01            1              04           00001
# 49         None        None         None            None            None
#
#    suffix                                        description  \
# 40    s2d          2D resampled+combined spectroscopic image
# 41    x1d       Extracted 1D spectra from combined exposures
# 42  uncal                               Raw 4D exposure data
# 43    cal  2D fully calibrated data averaged over all int...
# 44    cal  2D fully calibrated data averaged over all int...
# 45   rate  2D slope images derived after averaging of all...
# 46   rate  2D slope images derived after averaging of all...
# 47    x1d       Extracted 1D spectra from combined exposures
# 48    x1d       Extracted 1D spectra from combined exposures
# 49    s2d          2D resampled+combined spectroscopic image
#
#                   units stage
# 40                 none     1
# 41                 flux     1
# 42                   DN     1
# 43  DN/s or mJy/arcsec2     1
# 44  DN/s or mJy/arcsec2     1
# 45                 DN/s     1
# 46                 DN/s     1
# 47                 flux     1
# 48                 flux     1
# 49                 none     1

# %%
for row in c.execute('SELECT * FROM products'):
    print(row)
# Out:
# (0, 'jw00035001001_01101_00001_mirimage_cal.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (1, 'jw00035001001_01101_00001_mirimage_cal.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (2, 'jw00035001001_01101_00001_mirimage_rate.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (3, 'jw00035001001_01101_00001_mirimage_rate.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (4, 'jw00035001001_01101_00001_mirimage_x1d.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (5, 'jw00035001001_01101_00001_mirimage_x1d.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (6, 'jw00035001001_01101_00002_mirimage_cal.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 2, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (7, 'jw00035001001_01101_00002_mirimage_rate.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 2, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (8, 'jw00035001001_01101_00002_mirimage_x1d.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 2, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (9, 'jw00035001001_01101_00003_mirimage_cal.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 3, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (10, 'jw00035001001_01101_00003_mirimage_rate.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 3, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (11, 'jw00035001001_01101_00003_mirimage_x1d.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 3, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (12, 'jw00035001001_01101_00004_mirimage_bsub.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 4, 'bsub', '2D background-subtracted spectral data averaged over all integrations', 'DN/s', 1)
# (13, 'jw00035001001_01101_00004_mirimage_cal.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 4, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (14, 'jw00035001001_01101_00004_mirimage_rate.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 4, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (15, 'jw00035001001_01101_00004_mirimage_x1d.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 4, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (16, 'jw00035001001_01101_00005_mirimage_bsub.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 5, 'bsub', '2D background-subtracted spectral data averaged over all integrations', 'DN/s', 1)
# (17, 'jw00035001001_01101_00005_mirimage_cal.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 5, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (18, 'jw00035001001_01101_00005_mirimage_rate.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 5, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (19, 'jw00035001001_01101_00005_mirimage_x1d.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 5, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (20, 'jw00035001001_01101_00006_mirimage_bsub.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 6, 'bsub', '2D background-subtracted spectral data averaged over all integrations', 'DN/s', 1)
# (21, 'jw00035001001_01101_00006_mirimage_cal.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 6, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (22, 'jw00035001001_01101_00006_mirimage_rate.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 6, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (23, 'jw00035001001_01101_00006_mirimage_x1d.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 6, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (24, 'jw00035001001_01101_00007_mirimage_bsub.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 7, 'bsub', '2D background-subtracted spectral data averaged over all integrations', 'DN/s', 1)
# (25, 'jw00035001001_01101_00007_mirimage_cal.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 7, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (26, 'jw00035001001_01101_00007_mirimage_rate.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 7, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (27, 'jw00035001001_01101_00007_mirimage_x1d.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 7, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (28, 'jw00035001001_01101_00008_mirimage_bsub.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 8, 'bsub', '2D background-subtracted spectral data averaged over all integrations', 'DN/s', 1)
# (29, 'jw00035001001_01101_00008_mirimage_cal.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 8, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (30, 'jw00035001001_01101_00008_mirimage_rate.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 8, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (31, 'jw00035001001_01101_00008_mirimage_x1d.fits', None, 35, 'miri', 'mirimage', None, None, None, 1, 1, 1, 1, 1, 8, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (32, 'jw10001001001_01101_00001_mirifushort_cal.fits', None, 10001, 'miri', 'mirifushort', None, None, None, 1, 1, 1, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (33, 'jw10001001001_01101_00001_mirifushort_rate.fits', None, 10001, 'miri', 'mirifushort', None, None, None, 1, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (34, 'jw10001001001_01101_00001_mirifushort_s3d.fits', None, 10001, 'miri', 'mirifushort', None, None, None, 1, 1, 1, 1, 1, 1, 's3d', '3D rectified and combined spectral cube', 'none', 1)
# (35, 'jw10001001001_01101_00001_mirifushort_x1d.fits', None, 10001, 'miri', 'mirifushort', None, None, None, 1, 1, 1, 1, 1, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (36, 'jw10001001001_01101_0001_nrca4_cal.fits', None, 10001, 'nircam', 'nrca4', None, None, None, 1, 1, 1, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (37, 'jw10001001001_01101_0002_nrca4_cal.fits', None, 10001, 'nircam', 'nrca4', None, None, None, 1, 1, 1, 1, 1, 2, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (38, 'jw10002001001_02101_00001_nrs1_cal.fits', None, 10002, 'nirspec', 'nrs1', None, None, None, 1, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (39, 'jw10002001001_02101_00001_nrs1_rate.fits', None, 10002, 'nirspec', 'nrs1', None, None, None, 1, 1, 2, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (40, 'jw10002001001_02101_00001_nrs1_s2d.fits', None, 10002, 'nirspec', 'nrs1', None, None, None, 1, 1, 2, 1, 1, 1, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (41, 'jw10002001001_02101_00001_nrs1_x1d.fits', None, 10002, 'nirspec', 'nrs1', None, None, None, 1, 1, 2, 1, 1, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (42, 'jw11001001001_01101_00001_NRCA1_uncal.fits', None, 11001, 'nircam', 'NRCA1', None, None, None, 1, 1, 1, 1, 1, 1, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (43, 'jw11111001001_01104_00001_nrcalong_cal.fits', None, 11111, 'nircam', 'nrcalong', None, None, None, 1, 1, 1, 1, 4, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (44, 'jw11111001001_01104_00001_nrcalong_cal.fits', None, 11111, 'nircam', 'nrcalong', None, None, None, 1, 1, 1, 1, 4, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (45, 'jw11111001001_01104_00001_nrcalong_rate.fits', None, 11111, 'nircam', 'nrcalong', None, None, None, 1, 1, 1, 1, 4, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (46, 'jw11111001001_01104_00001_nrcalong_rate.fits', None, 11111, 'nircam', 'nrcalong', None, None, None, 1, 1, 1, 1, 4, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (47, 'jw11111001001_01104_00001_nrcalong_x1d.fits', None, 11111, 'nircam', 'nrcalong', None, None, None, 1, 1, 1, 1, 4, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (48, 'jw11111001001_01104_00001_nrcalong_x1d.fits', None, 11111, 'nircam', 'nrcalong', None, None, None, 1, 1, 1, 1, 4, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (49, 'jw80600-a3002_t001_miri_p750l_s2d.fits', 'a3002', 80600, 'miri', None, "'p750l'", 't001', None, None, None, None, None, None, None, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (50, 'jw80600-a3002_t001_miri_p750l_s2d.fits', 'a3002', 80600, 'miri', None, "'p750l'", 't001', None, None, None, None, None, None, None, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (51, 'jw80600-a3002_t001_miri_p750l_x1d.fits', 'a3002', 80600, 'miri', None, "'p750l'", 't001', None, None, None, None, None, None, None, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (52, 'jw80600-a3002_t001_miri_p750l_x1d.fits', 'a3002', 80600, 'miri', None, "'p750l'", 't001', None, None, None, None, None, None, None, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (53, 'jw80600012001_02101_00003_mirimage_calints.fits', None, 80600, 'miri', 'mirimage', None, None, None, 12, 1, 2, 1, 1, 3, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (54, 'jw80600012001_02101_00003_mirimage_rateints.fits', None, 80600, 'miri', 'mirimage', None, None, None, 12, 1, 2, 1, 1, 3, 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', 1)
# (55, 'jw80600012001_02101_00003_mirimage_x1d.fits', None, 80600, 'miri', 'mirimage', None, None, None, 12, 1, 2, 1, 1, 3, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (56, 'jw80600013001_02101_00001_mirimage_a3002_crf.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 1, 'crf', 'Copy of _cal with DQ array updated by outlier_detection step', 'DN/s', 1)
# (57, 'jw80600013001_02101_00001_mirimage_cal.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (58, 'jw80600013001_02101_00001_mirimage_cal.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (59, 'jw80600013001_02101_00001_mirimage_rate.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (60, 'jw80600013001_02101_00001_mirimage_uncal.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 1, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (61, 'jw80600013001_02101_00001_mirimage_x1d.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (62, 'jw80600013001_02101_00002_mirimage_a3002_crf.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 2, 'crf', 'Copy of _cal with DQ array updated by outlier_detection step', 'DN/s', 1)
# (63, 'jw80600013001_02101_00002_mirimage_cal.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 2, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (64, 'jw80600013001_02101_00002_mirimage_cal.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 2, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (65, 'jw80600013001_02101_00002_mirimage_rate.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 2, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (66, 'jw80600013001_02101_00002_mirimage_uncal.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 2, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (67, 'jw80600013001_02101_00002_mirimage_x1d.fits', None, 80600, 'miri', 'mirimage', None, None, None, 13, 1, 2, 1, 1, 2, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (68, 'jw82600047001_02102_00001_nrcb3_calints.fits', None, 82600, 'nircam', 'nrcb3', None, None, None, 47, 1, 2, 1, 2, 1, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (69, 'jw82600047001_02102_00001_nrcb3_rate.fits', None, 82600, 'nircam', 'nrcb3', None, None, None, 47, 1, 2, 1, 2, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (70, 'jw82600047001_02102_00001_nrcb3_rateints.fits', None, 82600, 'nircam', 'nrcb3', None, None, None, 47, 1, 2, 1, 2, 1, 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', 1)
# (71, 'jw82600047001_02102_00001_nrcb3_uncal.fits', None, 82600, 'nircam', 'nrcb3', None, None, None, 47, 1, 2, 1, 2, 1, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (72, 'jw82600049001_02102_00001_nrcblong_calints.fits', None, 82600, 'nircam', 'nrcblong', None, None, None, 49, 1, 2, 1, 2, 1, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (73, 'jw82600049001_02102_00001_nrcblong_rate.fits', None, 82600, 'nircam', 'nrcblong', None, None, None, 49, 1, 2, 1, 2, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (74, 'jw82600049001_02102_00001_nrcblong_rateints.fits', None, 82600, 'nircam', 'nrcblong', None, None, None, 49, 1, 2, 1, 2, 1, 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', 1)
# (75, 'jw82600049001_02102_00001_nrcblong_uncal.fits', None, 82600, 'nircam', 'nrcblong', None, None, None, 49, 1, 2, 1, 2, 1, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (76, 'jw82600051001_02102_00001_nrcalong_calints.fits', None, 82600, 'nircam', 'nrcalong', None, None, None, 51, 1, 2, 1, 2, 1, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (77, 'jw82600051001_02102_00001_nrcalong_rate.fits', None, 82600, 'nircam', 'nrcalong', None, None, None, 51, 1, 2, 1, 2, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (78, 'jw82600051001_02102_00001_nrcalong_rateints.fits', None, 82600, 'nircam', 'nrcalong', None, None, None, 51, 1, 2, 1, 2, 1, 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', 1)
# (79, 'jw82600051001_02102_00001_nrcalong_uncal.fits', None, 82600, 'nircam', 'nrcalong', None, None, None, 51, 1, 2, 1, 2, 1, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (80, 'jw84600007001_02101_00001_nrs1_cal.fits', None, 84600, 'nirspec', 'nrs1', None, None, None, 7, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (81, 'jw84600007001_02101_00001_nrs1_rate.fits', None, 84600, 'nirspec', 'nrs1', None, None, None, 7, 1, 2, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (82, 'jw84600007001_02101_00001_nrs1_s3d.fits', None, 84600, 'nirspec', 'nrs1', None, None, None, 7, 1, 2, 1, 1, 1, 's3d', '3D rectified and combined spectral cube', 'none', 1)
# (83, 'jw84600007001_02101_00001_nrs1_x1d.fits', None, 84600, 'nirspec', 'nrs1', None, None, None, 7, 1, 2, 1, 1, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (84, 'jw87600-a3001_t001_niriss_clear-gr700xd_x1dints.fits', 'a3001', 87600, 'niriss', None, "'clear-gr700xd'", 't001', None, None, None, None, None, None, None, 'x1dints', 'Extracted 1D spectra per integration', 'flux', 1)
# (85, 'jw87600-a3001_t001_niriss_f480m-nrm_amiavg.fits', 'a3001', 87600, 'niriss', None, "'f480m-nrm'", 't001', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', 1)
# (86, 'jw87600-a3001_t001_niriss_f480m-nrm_aminorm.fits', 'a3001', 87600, 'niriss', None, "'f480m-nrm'", 't001', None, None, None, None, None, None, None, 'aminorm', 'Final single product for the target corrected by the calibrator', 'none', 1)
# (87, 'jw87600-a3001_t002_niriss_f480m-nrm_amiavg.fits', 'a3001', 87600, 'niriss', None, "'f480m-nrm'", 't002', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', 1)
# (88, 'jw87600-a3001_t1_niriss_f480m-nrm_amiavg.fits', 'a3001', 87600, 'niriss', None, "'f480m-nrm'", 't1', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', 1)
# (89, 'jw87600-a3001_t1_niriss_f480m-nrm_aminorm.fits', 'a3001', 87600, 'niriss', None, "'f480m-nrm'", 't1', None, None, None, None, None, None, None, 'aminorm', 'Final single product for the target corrected by the calibrator', 'none', 1)
# (90, 'jw87600-a3001_t2_niriss_f480m-nrm_amiavg.fits', 'a3001', 87600, 'niriss', None, "'f480m-nrm'", 't2', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', 1)
# (91, 'jw87600-a3002_t001_niriss_f480m-nrm_amiavg.fits', 'a3002', 87600, 'niriss', None, "'f480m-nrm'", 't001', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', 1)
# (92, 'jw87600-a3002_t001_niriss_f480m-nrm_aminorm.fits', 'a3002', 87600, 'niriss', None, "'f480m-nrm'", 't001', None, None, None, None, None, None, None, 'aminorm', 'Final single product for the target corrected by the calibrator', 'none', 1)
# (93, 'jw87600-a3002_t002_niriss_f480m-nrm_amiavg.fits', 'a3002', 87600, 'niriss', None, "'f480m-nrm'", 't002', None, None, None, None, None, None, None, 'amiavg', 'Table of averaged fringe parameters for PSF reference or science target exposures', 'none', 1)
# (94, 'jw87600017001_02101_00002_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 17, 1, 2, 1, 1, 2, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (95, 'jw87600017001_02101_00002_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 17, 1, 2, 1, 1, 2, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (96, 'jw87600017001_02101_00002_nis_rate.fits', None, 87600, 'niriss', 'nis', None, None, None, 17, 1, 2, 1, 1, 2, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (97, 'jw87600017001_02101_00002_nis_rate.fits', None, 87600, 'niriss', 'nis', None, None, None, 17, 1, 2, 1, 1, 2, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (98, 'jw87600017001_02101_00002_nis_x1d.fits', None, 87600, 'niriss', 'nis', None, None, None, 17, 1, 2, 1, 1, 2, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (99, 'jw87600017001_02101_00002_nis_x1d.fits', None, 87600, 'niriss', 'nis', None, None, None, 17, 1, 2, 1, 1, 2, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (100, 'jw87600024001_02101_00001_nis_a3001_crf.fits', None, 87600, 'niriss', 'nis', None, None, None, 24, 1, 2, 1, 1, 1, 'crf', 'Copy of _cal with DQ array updated by outlier_detection step', 'DN/s', 1)
# (101, 'jw87600024001_02101_00001_nis_calints.fits', None, 87600, 'niriss', 'nis', None, None, None, 24, 1, 2, 1, 1, 1, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (102, 'jw87600024001_02101_00001_nis_rateints.fits', None, 87600, 'niriss', 'nis', None, None, None, 24, 1, 2, 1, 1, 1, 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', 1)
# (103, 'jw87600024001_02101_00001_nis_uncal.fits', None, 87600, 'niriss', 'nis', None, None, None, 24, 1, 2, 1, 1, 1, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (104, 'jw87600024001_02101_00001_nis_x1dints.fits', None, 87600, 'niriss', 'nis', None, None, None, 24, 1, 2, 1, 1, 1, 'x1dints', 'Extracted 1D spectra per integration', 'flux', 1)
# (105, 'jw87600027001_02101_00001_nis_a3001_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 1, 'ami', 'Output of ami_analyze step', 'none', 1)
# (106, 'jw87600027001_02101_00001_nis_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 1, 'ami', 'Output of ami_analyze step', 'none', 1)
# (107, 'jw87600027001_02101_00001_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (108, 'jw87600027001_02101_00001_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (109, 'jw87600027001_02101_00001_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (110, 'jw87600027001_02101_00001_nis_rate.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (111, 'jw87600027001_02101_00001_nis_uncal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 1, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (112, 'jw87600027001_02101_00002_nis_a3001_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 2, 'ami', 'Output of ami_analyze step', 'none', 1)
# (113, 'jw87600027001_02101_00002_nis_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 2, 'ami', 'Output of ami_analyze step', 'none', 1)
# (114, 'jw87600027001_02101_00002_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 2, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (115, 'jw87600027001_02101_00002_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 2, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (116, 'jw87600027001_02101_00003_nis_a3001_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 3, 'ami', 'Output of ami_analyze step', 'none', 1)
# (117, 'jw87600027001_02101_00003_nis_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 3, 'ami', 'Output of ami_analyze step', 'none', 1)
# (118, 'jw87600027001_02101_00003_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 3, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (119, 'jw87600027001_02101_00003_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 3, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (120, 'jw87600027001_02101_00004_nis_a3001_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 4, 'ami', 'Output of ami_analyze step', 'none', 1)
# (121, 'jw87600027001_02101_00004_nis_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 4, 'ami', 'Output of ami_analyze step', 'none', 1)
# (122, 'jw87600027001_02101_00004_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 4, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (123, 'jw87600027001_02101_00004_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 4, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (124, 'jw87600027001_02101_00005_nis_a3001_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 5, 'ami', 'Output of ami_analyze step', 'none', 1)
# (125, 'jw87600027001_02101_00005_nis_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 5, 'ami', 'Output of ami_analyze step', 'none', 1)
# (126, 'jw87600027001_02101_00005_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 5, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (127, 'jw87600027001_02101_00005_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 5, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (128, 'jw87600027001_02101_00006_nis_a3001_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 6, 'ami', 'Output of ami_analyze step', 'none', 1)
# (129, 'jw87600027001_02101_00006_nis_ami.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 6, 'ami', 'Output of ami_analyze step', 'none', 1)
# (130, 'jw87600027001_02101_00006_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 6, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (131, 'jw87600027001_02101_00006_nis_cal.fits', None, 87600, 'niriss', 'nis', None, None, None, 27, 1, 2, 1, 1, 6, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (132, 'jw93065002001_02101_00001_nrca1_a3001_crfints.fits', None, 93065, 'nircam', 'nrca1', None, None, None, 2, 1, 2, 1, 1, 1, 'crfints', '3D calibrated data with DQ array updated by outlier_detection step', 'DN/s', 1)
# (133, 'jw93065002001_02101_00001_nrca1_calints.fits', None, 93065, 'nircam', 'nrca1', None, None, None, 2, 1, 2, 1, 1, 1, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (134, 'jw93065002001_02101_00001_nrca1_rate.fits', None, 93065, 'nircam', 'nrca1', None, None, None, 2, 1, 2, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (135, 'jw93065002001_02101_00001_nrca1_rateints.fits', None, 93065, 'nircam', 'nrca1', None, None, None, 2, 1, 2, 1, 1, 1, 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', 1)
# (136, 'jw93065002001_02101_00001_nrca1_uncal.fits', None, 93065, 'nircam', 'nrca1', None, None, None, 2, 1, 2, 1, 1, 1, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (137, 'jw94015001002_02104_00001_nrcalong_rate.fits', None, 94015, 'nircam', 'nrcalong', None, None, None, 1, 2, 2, 1, 4, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (138, 'jw94015002001_02101_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (139, 'jw94015002001_02102_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, 2, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (140, 'jw94015002001_02103_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, 3, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (141, 'jw94015002001_02104_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, 4, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (142, 'jw94015002001_02105_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, 5, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (143, 'jw94015002001_02106_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, 6, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (144, 'jw94015002001_02107_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, 7, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (145, 'jw94015002001_02108_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, 8, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (146, 'jw94015002001_02109_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, 9, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (147, 'jw94015002001_0210A_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, '0A', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (148, 'jw94015002001_0210B_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, '0B', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (149, 'jw94015002001_0210C_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 1, 2, 1, '0C', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (150, 'jw94015002002_02101_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (151, 'jw94015002002_02102_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, 2, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (152, 'jw94015002002_02103_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, 3, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (153, 'jw94015002002_02104_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, 4, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (154, 'jw94015002002_02105_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, 5, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (155, 'jw94015002002_02106_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, 6, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (156, 'jw94015002002_02107_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, 7, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (157, 'jw94015002002_02108_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, 8, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (158, 'jw94015002002_02109_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, 9, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (159, 'jw94015002002_0210A_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, '0A', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (160, 'jw94015002002_0210B_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, '0B', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (161, 'jw94015002002_0210C_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 2, 2, 2, 1, '0C', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (162, 'jw94015004001_02101_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (163, 'jw94015004001_02102_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, 2, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (164, 'jw94015004001_02103_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, 3, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (165, 'jw94015004001_02104_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, 4, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (166, 'jw94015004001_02105_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, 5, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (167, 'jw94015004001_02106_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, 6, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (168, 'jw94015004001_02107_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, 7, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (169, 'jw94015004001_02108_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, 8, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (170, 'jw94015004001_02109_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, 9, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (171, 'jw94015004001_0210A_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, '0A', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (172, 'jw94015004001_0210B_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, '0B', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (173, 'jw94015004001_0210C_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 1, 2, 1, '0C', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (174, 'jw94015004002_02101_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (175, 'jw94015004002_02102_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, 2, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (176, 'jw94015004002_02103_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, 3, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (177, 'jw94015004002_02104_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, 4, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (178, 'jw94015004002_02105_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, 5, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (179, 'jw94015004002_02106_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, 6, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (180, 'jw94015004002_02107_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, 7, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (181, 'jw94015004002_02108_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, 8, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (182, 'jw94015004002_02109_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, 9, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (183, 'jw94015004002_0210A_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, '0A', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (184, 'jw94015004002_0210B_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, '0B', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (185, 'jw94015004002_0210C_00001_mirimage_cal.fits', None, 94015, 'miri', 'mirimage', None, None, None, 4, 2, 2, 1, '0C', 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (186, 'jw95065-a3001_s00001_nirspec_f100lp-g140m_cal.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00001', None, None, None, None, None, None, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (187, 'jw95065-a3001_s00001_nirspec_f100lp-g140m_crf.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00001', None, None, None, None, None, None, 'crf', 'Copy of _cal with DQ array updated by outlier_detection step', 'DN/s', 1)
# (188, 'jw95065-a3001_s00001_nirspec_f100lp-g140m_s2d.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00001', None, None, None, None, None, None, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (189, 'jw95065-a3001_s00001_nirspec_f100lp-g140m_x1d.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00001', None, None, None, None, None, None, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (190, 'jw95065-a3001_s00002_nirspec_f100lp-g140m_cal.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00002', None, None, None, None, None, None, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (191, 'jw95065-a3001_s00002_nirspec_f100lp-g140m_crf.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00002', None, None, None, None, None, None, 'crf', 'Copy of _cal with DQ array updated by outlier_detection step', 'DN/s', 1)
# (192, 'jw95065-a3001_s00002_nirspec_f100lp-g140m_s2d.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00002', None, None, None, None, None, None, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (193, 'jw95065-a3001_s00002_nirspec_f100lp-g140m_x1d.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00002', None, None, None, None, None, None, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (194, 'jw95065-a3001_s00003_nirspec_f100lp-g140m_cal.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00003', None, None, None, None, None, None, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (195, 'jw95065-a3001_s00003_nirspec_f100lp-g140m_crf.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00003', None, None, None, None, None, None, 'crf', 'Copy of _cal with DQ array updated by outlier_detection step', 'DN/s', 1)
# (196, 'jw95065-a3001_s00003_nirspec_f100lp-g140m_s2d.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00003', None, None, None, None, None, None, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (197, 'jw95065-a3001_s00003_nirspec_f100lp-g140m_x1d.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m'", None, 's00003', None, None, None, None, None, None, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (198, 'jw95065-a3001_s12_nirspec_f100lp_g140m_cal.fits', 'a3001', 95065, 'nirspec', None, "'f100lp', 'g140m'", None, 's12', None, None, None, None, None, None, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (199, 'jw95065-a3001_s13_nirspec_f100lp_g140m_cal.fits', 'a3001', 95065, 'nirspec', None, "'f100lp', 'g140m'", None, 's13', None, None, None, None, None, None, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (200, 'jw95065-a3001_t001_nirspec_f100lp-g140m_s00001_cal.fits', 'a3001', 95065, 'nirspec', None, "'f100lp-g140m', 's00001'", 't001', None, None, None, None, None, None, None, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (201, 'jw95065006001_02101_00001_nrs1_cal.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (202, 'jw95065006001_02101_00001_nrs1_cal.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (203, 'jw95065006001_02101_00001_nrs1_rate.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (204, 'jw95065006001_02101_00001_nrs1_s2d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 1, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (205, 'jw95065006001_02101_00001_nrs1_s2d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 1, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (206, 'jw95065006001_02101_00001_nrs1_uncal.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 1, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (207, 'jw95065006001_02101_00001_nrs1_x1d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (208, 'jw95065006001_02101_00001_nrs1_x1d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (209, 'jw95065006001_02101_00002_nrs1_cal.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 2, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (210, 'jw95065006001_02101_00002_nrs1_cal.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 2, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (211, 'jw95065006001_02101_00002_nrs1_rate.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 2, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (212, 'jw95065006001_02101_00002_nrs1_s2d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 2, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (213, 'jw95065006001_02101_00002_nrs1_s2d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 2, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (214, 'jw95065006001_02101_00002_nrs1_uncal.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 2, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (215, 'jw95065006001_02101_00002_nrs1_x1d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 2, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (216, 'jw95065006001_02101_00002_nrs1_x1d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 2, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (217, 'jw95065006001_02101_00003_nrs1_cal.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 3, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (218, 'jw95065006001_02101_00003_nrs1_cal.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 3, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (219, 'jw95065006001_02101_00003_nrs1_rate.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 3, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (220, 'jw95065006001_02101_00003_nrs1_s2d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 3, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (221, 'jw95065006001_02101_00003_nrs1_s2d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 3, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (222, 'jw95065006001_02101_00003_nrs1_uncal.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 3, 'uncal', 'Raw 4D exposure data', 'DN', 1)
# (223, 'jw95065006001_02101_00003_nrs1_x1d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 3, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (224, 'jw95065006001_02101_00003_nrs1_x1d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 6, 1, 2, 1, 1, 3, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (225, 'jw95065008001_02101_00001_nrs1_cal.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 8, 1, 2, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (226, 'jw95065008001_02101_00001_nrs1_rate.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 8, 1, 2, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (227, 'jw95065008001_02101_00001_nrs1_s2d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 8, 1, 2, 1, 1, 1, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (228, 'jw95065008001_02101_00001_nrs1_x1d.fits', None, 95065, 'nirspec', 'nrs1', None, None, None, 8, 1, 2, 1, 1, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (229, 'jw96090001001_03101_00001_nrca1_cal.fits', None, 96090, 'nircam', 'nrca1', None, None, None, 1, 1, 3, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# ...
# (267, 'jw96090001004_03101_00001_nrcb4_cal.fits', None, 96090, 'nircam', 'nrcb4', None, None, None, 1, 4, 3, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (268, 'jw96090001004_03101_00001_nrcblong_cal.fits', None, 96090, 'nircam', 'nrcblong', None, None, None, 1, 4, 3, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (269, 'jw99999-a3001_t001_nircam_f140m-maskbar_i2d.fits', 'a3001', 99999, 'nircam', None, "'f140m-maskbar'", 't001', None, None, None, None, None, None, None, 'i2d', '2D rectified and combined image', 'none', 1)
# (270, 'jw99999-a3001_t001_nircam_f140m-maskbar_psfstack.fits', 'a3001', 99999, 'nircam', None, "'f140m-maskbar'", 't001', None, None, None, None, None, None, None, 'psfstack', '3D stack of PSF images from stack_refs step', 'none', 1)
# (271, 'jw99999-a3001_t001_nircam_f410m-clear_i2d.fits', 'a3001', 99999, 'nircam', None, "'f410m-clear'", 't001', None, None, None, None, None, None, None, 'i2d', '2D rectified and combined image', 'none', 1)
# (272, 'jw99999-a3001_t1_nircam_f140m-maskbar_i2d.fits', 'a3001', 99999, 'nircam', None, "'f140m-maskbar'", 't1', None, None, None, None, None, None, None, 'i2d', '2D rectified and combined image', 'none', 1)
# (273, 'jw99999-a3001_t1_nircam_f140m-maskbar_psfstack.fits', 'a3001', 99999, 'nircam', None, "'f140m-maskbar'", 't1', None, None, None, None, None, None, None, 'psfstack', '3D stack of PSF images from stack_refs step', 'none', 1)
# (274, 'jw99999001001_03101_00001_nrcalong_cal.fits', None, 99999, 'nircam', 'nrcalong', None, None, None, 1, 1, 3, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (275, 'jw99999001002_03101_00001_nrcalong_cal.fits', None, 99999, 'nircam', 'nrcalong', None, None, None, 1, 2, 3, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (276, 'jw99999001003_03101_00001_nrcalong_cal.fits', None, 99999, 'nircam', 'nrcalong', None, None, None, 1, 3, 3, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (277, 'jw9999947001_02102_00001_nrcb3_a3001_crfints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 1, 'crfints', '3D calibrated data with DQ array updated by outlier_detection step', 'DN/s', 1)
# (278, 'jw9999947001_02102_00001_nrcb3_a3001_psfalign.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 1, 'psfalign', '4D array of PSF images aligned to individual integrations of science target images', 'none', 1)
# (279, 'jw9999947001_02102_00001_nrcb3_a3001_psfsub.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 1, 'psfsub', 'PSF subtracted', 'none', 1)
# (280, 'jw9999947001_02102_00001_nrcb3_calints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 1, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (281, 'jw9999947001_02102_00001_nrcb3_calints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 1, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (282, 'jw9999947001_02102_00001_nrcb3_psfalign.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 1, 'psfalign', '4D array of PSF images aligned to individual integrations of science target images', 'none', 1)
# (283, 'jw9999947001_02102_00001_nrcb3_psfsub.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 1, 'psfsub', 'PSF subtracted', 'none', 1)
# (284, 'jw9999947001_02102_00001_nrcb3_rateints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 1, 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', 1)
# (285, 'jw9999947001_02102_00002_nrcb3_a3001_crfints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 2, 'crfints', '3D calibrated data with DQ array updated by outlier_detection step', 'DN/s', 1)
# (286, 'jw9999947001_02102_00002_nrcb3_a3001_psfalign.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 2, 'psfalign', '4D array of PSF images aligned to individual integrations of science target images', 'none', 1)
# (287, 'jw9999947001_02102_00002_nrcb3_a3001_psfsub.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 2, 'psfsub', 'PSF subtracted', 'none', 1)
# (288, 'jw9999947001_02102_00002_nrcb3_calints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 2, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (289, 'jw9999947001_02102_00002_nrcb3_calints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 2, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (290, 'jw9999947001_02102_00002_nrcb3_psfalign.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 2, 'psfalign', '4D array of PSF images aligned to individual integrations of science target images', 'none', 1)
# (291, 'jw9999947001_02102_00002_nrcb3_psfsub.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 2, 'psfsub', 'PSF subtracted', 'none', 1)
# (292, 'jw9999947001_02102_00002_nrcb3_rateints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 2, 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', 1)
# (293, 'jw9999947001_02102_00003_nrcb3_calints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 3, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (294, 'jw9999947001_02102_00003_nrcb3_calints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 3, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (295, 'jw9999947001_02102_00003_nrcb3_rateints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 3, 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', 1)
# (296, 'jw9999947001_02102_00004_nrcb3_calints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 4, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (297, 'jw9999947001_02102_00004_nrcb3_calints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 4, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (298, 'jw9999947001_02102_00004_nrcb3_rateints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 4, 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', 1)
# (299, 'jw9999947001_02102_00005_nrcb3_calints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 5, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (300, 'jw9999947001_02102_00005_nrcb3_calints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 5, 'calints', 'Calibrated slope images for each integration', 'DN/s', 1)
# (301, 'jw9999947001_02102_00005_nrcb3_rateints.fits', None, 99999, 'nircam', 'nrcb3', None, None, None, 470, 1, 2, 1, 2, 5, 'rateints', '3D slope images for each integration, result of ramp fitting', 'DN/s', 1)
# (302, 'jwtest1001001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 1, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (303, 'jwtest1002001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 2, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (304, 'jwtest1003001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 3, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (305, 'jwtest1004001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 4, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (306, 'jwtest1005001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 5, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (307, 'jwtest1006001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 6, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (308, 'jwtest1007001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 7, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (309, 'jwtest1008001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 8, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (310, 'jwtest1009001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 9, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (311, 'jwtest1010001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 10, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (312, 'jwtest1011001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 11, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (313, 'jwtest1012001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 12, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (314, 'jwtest1013001_01101_00001_NRS1_cal.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 13, 1, 1, 1, 1, 1, 'cal', '2D fully calibrated data averaged over all integrations', 'DN/s or mJy/arcsec2', 1)
# (315, 'jwtest1013001_01101_00001_NRS1_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 13, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (316, 'jwtest1013001_01101_00001_NRS1_s2d.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 13, 1, 1, 1, 1, 1, 's2d', '2D resampled+combined spectroscopic image', 'none', 1)
# (317, 'jwtest1013001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 13, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (318, 'jwtest1013001_01101_00001_NRS1_x1d.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 13, 1, 1, 1, 1, 1, 'x1d', 'Extracted 1D spectra from combined exposures', 'flux', 1)
# (319, 'jwtest1014001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 14, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (320, 'jwtest1015001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 15, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (321, 'jwtest1016001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 16, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (322, 'jwtest1017001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 17, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (323, 'jwtest1018001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 18, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (324, 'jwtest1019001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 19, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (325, 'jwtest1020001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 20, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (326, 'jwtest1021001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 21, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (327, 'jwtest1022001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 22, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (328, 'jwtest1023001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 23, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (329, 'jwtest1024001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 24, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (330, 'jwtest1025001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 25, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (331, 'jwtest1026001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 26, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (332, 'jwtest1027001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 27, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (333, 'jwtest1028001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 28, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (334, 'jwtest1029001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 29, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (335, 'jwtest1030001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 30, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (336, 'jwtest1031001_01101_00001_NRS1_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS1', None, None, None, 31, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (337, 'jwtest1032001_01101_00001_NRS2_uncal_rate.fits', None, 'test1', 'nirspec', 'NRS2', None, None, None, 32, 1, 1, 1, 1, 1, 'rate', '2D slope images derived after averaging of all countrate integrations within the exposure', 'DN/s', 1)
# (338, 'real_soss_disp_mode_250_8_96_2048_uncal.fits', None, 'al', 'disp', None, None, None, 'soss', '', '', None, None, None, None, 'uncal', 'Raw 4D exposure data', 'DN', 1)

# %%
import time

class JWSTAssociation():
    
    def __init__(self, filename):
        self.filename = filename
        self.full = filename.split('.')[0]
        self.formatted = True
        in_chunks = self.full.split('_')
        
        print(in_chunks)
        if len(in_chunks) < 5:
            self.formatted = False
            return
            
        first = in_chunks[0][2:].split('-')
        if len(first) == 1:
            self.formatted = False
            return
        self.program_id = first[0]
        self.ac_id = first[1]
        
        second = in_chunks[1]
        #t = time.strptime(second, '%Y%m%dT%H%M%S')
        #self.datetime = time.strftime("%Y %b %d, %X", t)
        second = second.lower().split('t')[0]
        t = time.strptime(second, '%Y%m%d')
        self.datetime = time.strftime("%Y %b %d", t)
        
        self.pipeline_element = in_chunks[2]
        
        self.number = in_chunks[3]
        
        self.tuple_ = (self.filename,
                       self.program_id,
                       self.ac_id,
                       self.pipeline_element,
                       self.datetime,
                       self.number
                      )

# %%
def add_associations_to_db(assn_list, c, conn):
    
    columns = ['file',
               'program_id',
               'ac_id',
               'pipeline',
               'datetime',
               'number'
              ]
    
    df = pd.DataFrame()
    for a in sorted(assn_list):
        assn = JWSTAssociation(a)
        if assn.formatted:
            assn_fields = list(assn.tuple_)
            print(assn_fields)
            new_row = pd.DataFrame(columns=columns, data=[assn_fields])
            df = df.append(new_row, ignore_index=True)
        else:
            continue
                
    df.to_sql("associations", conn, if_exists="replace", dtype='string')
    return df

# %%
print(ASSN)
frame2 = add_associations_to_db(ASSN, c, conn)
# Out:
# ['._test_asn17.json', 'extract1d_pars.json', 'jw00035_o001_20170706t153400_spec2_001_asn.json', 'jw10001_20160520T114200_dither_001_asn.json', 'jw111110-a3001_20171109T145456_spec2_001_asn.json', 'jw111110-a3001_20171109T145456_spec2_001_asn.json', 'jw80600-a3002_20170227t160430_spec2_001_asn.json', 'jw80600-a3002_20170227t160430_spec3_001_asn.json', 'jw80600-a3002_20170227t160430_spec3_001_asn.json', 'jw87600-a3001_20170327t343434_ami3_001_asn.json', 'jw87600-a3001_20170327t343434_ami3_001_asn.json', 'jw87600-a3001_20170527t111213_tso3_001_asn.json', 'jw87600-a3001_20171109T145456_spec2_001_asn.json', 'jw87600-a3001_20171109T145456_spec2_001_asn.json', 'jw93065-a3001_20170511t111213_tso3_001_asn.json', 'jw94015_20160524T082730_mosaic_001_asn.json', 'jw95065-a3001_20170309t141001_spec2_001_asn.json', 'jw95065-a3001_20170309t141001_spec3_001_asn.json', 'jw95065-a3001_20170309t141001_spec3_001_asn.json', 'jw96090-a3001_20160415t035424_image3_001_asn.json', 'jw96090-a3001_20160415t035424_image3_002_asn.json', 'jw99999-a3001_20170327t121212_coron3_001_asn.json', 'jw99999-a3001_20170327t121212_coron3_001_asn.json', 'jw99999-a3001_20170717t162100_image3_001_asn.json', 'nircam_grism_asn.json', 'test_ami_asn.json', 'test_asn17.json', 'test_asn4.json', 'test_coron_asn.json']
# ['']
# ['extract1d', 'pars']
# ['jw00035', 'o001', '20170706t153400', 'spec2', '001', 'asn']
# ['jw10001', '20160520T114200', 'dither', '001', 'asn']
# ['jw111110-a3001', '20171109T145456', 'spec2', '001', 'asn']
# ['jw111110-a3001_20171109T145456_spec2_001_asn.json', '111110', 'a3001', 'spec2', '2017 Nov 09', '001']
# ['jw111110-a3001', '20171109T145456', 'spec2', '001', 'asn']
# ['jw111110-a3001_20171109T145456_spec2_001_asn.json', '111110', 'a3001', 'spec2', '2017 Nov 09', '001']
# ['jw80600-a3002', '20170227t160430', 'spec2', '001', 'asn']
# ['jw80600-a3002_20170227t160430_spec2_001_asn.json', '80600', 'a3002', 'spec2', '2017 Feb 27', '001']
# ['jw80600-a3002', '20170227t160430', 'spec3', '001', 'asn']
# ['jw80600-a3002_20170227t160430_spec3_001_asn.json', '80600', 'a3002', 'spec3', '2017 Feb 27', '001']
# ['jw80600-a3002', '20170227t160430', 'spec3', '001', 'asn']
# ['jw80600-a3002_20170227t160430_spec3_001_asn.json', '80600', 'a3002', 'spec3', '2017 Feb 27', '001']
# ['jw87600-a3001', '20170327t343434', 'ami3', '001', 'asn']
# ['jw87600-a3001_20170327t343434_ami3_001_asn.json', '87600', 'a3001', 'ami3', '2017 Mar 27', '001']
# ['jw87600-a3001', '20170327t343434', 'ami3', '001', 'asn']
# ['jw87600-a3001_20170327t343434_ami3_001_asn.json', '87600', 'a3001', 'ami3', '2017 Mar 27', '001']
# ['jw87600-a3001', '20170527t111213', 'tso3', '001', 'asn']
# ['jw87600-a3001_20170527t111213_tso3_001_asn.json', '87600', 'a3001', 'tso3', '2017 May 27', '001']
# ['jw87600-a3001', '20171109T145456', 'spec2', '001', 'asn']
# ['jw87600-a3001_20171109T145456_spec2_001_asn.json', '87600', 'a3001', 'spec2', '2017 Nov 09', '001']
# ['jw87600-a3001', '20171109T145456', 'spec2', '001', 'asn']
# ['jw87600-a3001_20171109T145456_spec2_001_asn.json', '87600', 'a3001', 'spec2', '2017 Nov 09', '001']
# ['jw93065-a3001', '20170511t111213', 'tso3', '001', 'asn']
# ['jw93065-a3001_20170511t111213_tso3_001_asn.json', '93065', 'a3001', 'tso3', '2017 May 11', '001']
# ['jw94015', '20160524T082730', 'mosaic', '001', 'asn']
# ['jw95065-a3001', '20170309t141001', 'spec2', '001', 'asn']
# ['jw95065-a3001_20170309t141001_spec2_001_asn.json', '95065', 'a3001', 'spec2', '2017 Mar 09', '001']
# ['jw95065-a3001', '20170309t141001', 'spec3', '001', 'asn']
# ['jw95065-a3001_20170309t141001_spec3_001_asn.json', '95065', 'a3001', 'spec3', '2017 Mar 09', '001']
# ['jw95065-a3001', '20170309t141001', 'spec3', '001', 'asn']
# ['jw95065-a3001_20170309t141001_spec3_001_asn.json', '95065', 'a3001', 'spec3', '2017 Mar 09', '001']
# ['jw96090-a3001', '20160415t035424', 'image3', '001', 'asn']
# ['jw96090-a3001_20160415t035424_image3_001_asn.json', '96090', 'a3001', 'image3', '2016 Apr 15', '001']
# ['jw96090-a3001', '20160415t035424', 'image3', '002', 'asn']
# ['jw96090-a3001_20160415t035424_image3_002_asn.json', '96090', 'a3001', 'image3', '2016 Apr 15', '002']
# ['jw99999-a3001', '20170327t121212', 'coron3', '001', 'asn']
# ['jw99999-a3001_20170327t121212_coron3_001_asn.json', '99999', 'a3001', 'coron3', '2017 Mar 27', '001']
# ['jw99999-a3001', '20170327t121212', 'coron3', '001', 'asn']
# ['jw99999-a3001_20170327t121212_coron3_001_asn.json', '99999', 'a3001', 'coron3', '2017 Mar 27', '001']
# ['jw99999-a3001', '20170717t162100', 'image3', '001', 'asn']
# ['jw99999-a3001_20170717t162100_image3_001_asn.json', '99999', 'a3001', 'image3', '2017 Jul 17', '001']
# ['nircam', 'grism', 'asn']
# ['test', 'ami', 'asn']
# ['test', 'asn17']
# ['test', 'asn4']
# ['test', 'coron', 'asn']

# %%
frame2
# Out:
#                                                  file program_id  ac_id  \
# 0   jw111110-a3001_20171109T145456_spec2_001_asn.json     111110  a3001
# 1   jw111110-a3001_20171109T145456_spec2_001_asn.json     111110  a3001
# 2    jw80600-a3002_20170227t160430_spec2_001_asn.json      80600  a3002
# 3    jw80600-a3002_20170227t160430_spec3_001_asn.json      80600  a3002
# 4    jw80600-a3002_20170227t160430_spec3_001_asn.json      80600  a3002
# 5     jw87600-a3001_20170327t343434_ami3_001_asn.json      87600  a3001
# 6     jw87600-a3001_20170327t343434_ami3_001_asn.json      87600  a3001
# 7     jw87600-a3001_20170527t111213_tso3_001_asn.json      87600  a3001
# 8    jw87600-a3001_20171109T145456_spec2_001_asn.json      87600  a3001
# 9    jw87600-a3001_20171109T145456_spec2_001_asn.json      87600  a3001
# 10    jw93065-a3001_20170511t111213_tso3_001_asn.json      93065  a3001
# 11   jw95065-a3001_20170309t141001_spec2_001_asn.json      95065  a3001
# 12   jw95065-a3001_20170309t141001_spec3_001_asn.json      95065  a3001
# 13   jw95065-a3001_20170309t141001_spec3_001_asn.json      95065  a3001
# 14  jw96090-a3001_20160415t035424_image3_001_asn.json      96090  a3001
# 15  jw96090-a3001_20160415t035424_image3_002_asn.json      96090  a3001
# 16  jw99999-a3001_20170327t121212_coron3_001_asn.json      99999  a3001
# 17  jw99999-a3001_20170327t121212_coron3_001_asn.json      99999  a3001
# 18  jw99999-a3001_20170717t162100_image3_001_asn.json      99999  a3001
#
#    pipeline     datetime number
# 0     spec2  2017 Nov 09    001
# 1     spec2  2017 Nov 09    001
# 2     spec2  2017 Feb 27    001
# 3     spec3  2017 Feb 27    001
# 4     spec3  2017 Feb 27    001
# 5      ami3  2017 Mar 27    001
# 6      ami3  2017 Mar 27    001
# 7      tso3  2017 May 27    001
# 8     spec2  2017 Nov 09    001
# 9     spec2  2017 Nov 09    001
# 10     tso3  2017 May 11    001
# 11    spec2  2017 Mar 09    001
# 12    spec3  2017 Mar 09    001
# 13    spec3  2017 Mar 09    001
# 14   image3  2016 Apr 15    001
# 15   image3  2016 Apr 15    002
# 16   coron3  2017 Mar 27    001
# 17   coron3  2017 Mar 27    001
# 18   image3  2017 Jul 17    001

# %%
row = c.execute('SELECT program_id FROM associations WHERE program_id=?', ['96090'])
for p in row:
    print(p)
print(row.rowcount)
# Out:
# (96090,)
# (96090,)
# -1

# %%
def get_exposure_programs_list(c):
    programs = []
    for row in c.execute('SELECT program_id FROM products'):
        programs.append(str(row[0]))
    programs = list(set(programs))
    return programs

# %%
PRODUCT_COLUMNS = ['file',
                   'assn_number',
                   'program_id',
                   'instrument',
                   'detector',
                   'optical_elements',
                   'target_id',
                   'source_id',
                   'obs_number',
                   'visit_number',
                   'visit_group',
                   'parallel_seq',
                   'activity_number',
                   'exposure_number',
                   'suffix',
                   'description',
                   'units',
                   'stage'
                  ]

ASSN_COLUMNS = ['file',
                'program_id',
                'ac_id',
                'pipeline',
                'datetime',
                'number'
               ]

# %%
def pair_associations_and_exposures(programs, c, conn):
    results = {}
    for p in programs:
        association_query = c.execute('SELECT * FROM associations WHERE program_id=?', [p])
        association_query = c.fetchall()
        associations = [aq[1:] for aq in association_query]
        if len(associations) > 0:
            exposure_query = c.execute('SELECT * FROM products WHERE program_id=?', [p])
            exposure_query = c.fetchall()
            exposures = [eq[1:] for eq in exposure_query]
            print(associations)
            associations_frame = pd.DataFrame(associations, columns=ASSN_COLUMNS)
            exposures_frame = pd.DataFrame(exposures, columns=PRODUCT_COLUMNS)
            associations_title = "{0}_associations".format(p)
            exposures_title = "{0}_exposures".format(p)
            results[p] = {'associations': associations_frame, 'exposures': exposures_frame}
            associations_frame.to_sql(associations_title, conn, if_exists="replace", dtype='string')
            exposures_frame.to_sql(exposures_title, conn, if_exists="replace", dtype='string')
        else:
            print("No association found for {0}".format(p))
    return results

# %%
def write_db_to_disk(new_db, c, conn):
    try:
        os.remove(new_db)
    except OSError:
        pass
    
    new_conn = sqlite3.connect(new_db)
    
    query = "".join(line for line in conn.iterdump())

    new_conn.executescript(query)
    
    new_conn.close()

# %%
programs = get_exposure_programs_list(c)
results = pair_associations_and_exposures(programs, c, conn)
write_db_to_disk('mydir_files.db', c, conn)
# Out:
# No association found for 11111
# [('jw87600-a3001_20170327t343434_ami3_001_asn.json', 87600, 'a3001', 'ami3', '2017 Mar 27', 1), ('jw87600-a3001_20170327t343434_ami3_001_asn.json', 87600, 'a3001', 'ami3', '2017 Mar 27', 1), ('jw87600-a3001_20170527t111213_tso3_001_asn.json', 87600, 'a3001', 'tso3', '2017 May 27', 1), ('jw87600-a3001_20171109T145456_spec2_001_asn.json', 87600, 'a3001', 'spec2', '2017 Nov 09', 1), ('jw87600-a3001_20171109T145456_spec2_001_asn.json', 87600, 'a3001', 'spec2', '2017 Nov 09', 1)]
# [('jw80600-a3002_20170227t160430_spec2_001_asn.json', 80600, 'a3002', 'spec2', '2017 Feb 27', 1), ('jw80600-a3002_20170227t160430_spec3_001_asn.json', 80600, 'a3002', 'spec3', '2017 Feb 27', 1), ('jw80600-a3002_20170227t160430_spec3_001_asn.json', 80600, 'a3002', 'spec3', '2017 Feb 27', 1)]
# No association found for test1
# No association found for 84600
# No association found for 94015
# No association found for 11001
# No association found for al
# [('jw93065-a3001_20170511t111213_tso3_001_asn.json', 93065, 'a3001', 'tso3', '2017 May 11', 1)]
# No association found for 10002
# [('jw95065-a3001_20170309t141001_spec2_001_asn.json', 95065, 'a3001', 'spec2', '2017 Mar 09', 1), ('jw95065-a3001_20170309t141001_spec3_001_asn.json', 95065, 'a3001', 'spec3', '2017 Mar 09', 1), ('jw95065-a3001_20170309t141001_spec3_001_asn.json', 95065, 'a3001', 'spec3', '2017 Mar 09', 1)]
# No association found for 10001
# No association found for 82600
# [('jw96090-a3001_20160415t035424_image3_001_asn.json', 96090, 'a3001', 'image3', '2016 Apr 15', 1), ('jw96090-a3001_20160415t035424_image3_002_asn.json', 96090, 'a3001', 'image3', '2016 Apr 15', 2)]
# [('jw99999-a3001_20170327t121212_coron3_001_asn.json', 99999, 'a3001', 'coron3', '2017 Mar 27', 1), ('jw99999-a3001_20170327t121212_coron3_001_asn.json', 99999, 'a3001', 'coron3', '2017 Mar 27', 1), ('jw99999-a3001_20170717t162100_image3_001_asn.json', 99999, 'a3001', 'image3', '2017 Jul 17', 1)]
# No association found for 35

# %%
c.close()
conn.close()

# %%
import time

x = '20160415T145456'
y = time.strptime(x, '%Y%m%dT%H%M%S')
print(y)
z = time.strftime("%Y %b %d, %X", y)
print(z)
